# %% [markdown]
# # 🏴‍☠️ Pirate Pain Classification Challenge
#
# > ⚓ *"Even pirates feel pain — let's teach the model to feel it too."*
#
# ---
#
# ## 📚 Table of Contents
# 0. [README](#readme)
# 1. [Setup & Configuration](#setup)
# 2. [Data Loading](#data-loading)
# 3. [Import Libraries](#import-libraries)
# 4. [Data Preprocessing](#data-preprocessing)
# 5. [Sequence Building](#sequence-building)
# 6. [DataLoaders](#dataloaders)
# 7. [Network Hyperparameters](#hyperparameters)
# 8. [Model Architecture](#model-architecture)
# 9. [Training Functions](#training-functions)
# 10. [Model Training](#model-training)
# 11. [Evaluation & Metrics](#evaluation)
# 12. [Model Loading & Final Testing](#model-loading)
# 13. [Competition Submission](#submission)
#
# ---
#
# ### ⚙️ Quick Configuration Map
#
# > 🧭 *"If ye seek to tweak the code, here be where to look!"*
#
# - 🧺 **Batch Size:** → [DataLoaders](#dataloaders)
# - ⚗️ **Hyperparameters:** → [Network Hyperparameters](#hyperparameters)
# - 🪞 **Window Size & Stride:** → [Sequence Building](#sequence-building)
# - ⚙️ **Model Type:** → [Setup & Configuration](#setup)
#
# ---
#
#
#
# ---
#
# ### 💰 Treasure Storage — Models & Submissions
# > 🏴‍☠️ *"A wise pirate always knows where his treasure be buried — guard yer models and submissions well!"*
#
# - 💾 **Model & Submission Save/Load Path:** → [Setup & Configuration](#setup)
#   - 🗂️ Models be saved in a **`models/`** folder with the name:
#     **`experiment_name_dd-mm-HH-MM.pt`** (day-month-hour-minute).
#   - 📜 Submissions be saved in a **`submissions/`** folder with the filename format:
#     **`experiment_name_dd-mm-HH-MM.csv`** .
#   - 🔡 All related model parameters are saved in **`models/`** folder with the  name **`experiment_name_dd-mm-HH-MM_config.json`** .
#
#
#   *❗The experiment name is set as **`RnnType_Bi_dd-mm-HH-MM`** or **`RnnType_dd-mm-HH-MM`** depending on if it is bidirectional or not*
# ---

# %% [markdown]
# <a id="readme"></a>
# ## 0. Info

# %% [markdown]
# This section lists all the main parameters that can be modified to control data loading, model behavior, and training.
#
# ---
#
# ### 📁 File Paths
# | Variable | Description | Default Value |
# |-----------|--------------|----------------|
# | `TRAIN_DATA_PATH` | Training features | `'pirate_pain_train.csv'` |
# | `TRAIN_LABELS_PATH` | Training labels | `'pirate_pain_train_labels.csv'` |
# | `TEST_DATA_PATH` | Test set for inference | `'pirate_pain_test.csv'` *(optional)* |
# | `MODEL_SAVE_PATH` | Output model file | `'pirate_model.pt'` |
# | `RESULTS_FILE` | CSV for predictions | `'results_<date-time>.csv'` |
#
# ---
#
# ### 🧠 Model & Architecture
# | Parameter | Description | Typical Values |
# |------------|--------------|----------------|
# | `model_type` | Choose model class | `'RNN'`, `'LSTM'`, `'GRU'`, `'ANN'` |
# | `input_size` | Number of features per time step | *auto-detected from data* |
# | `hidden_size` | Hidden layer size | `64`, `128`, `256` |
# | `num_layers` | Number of RNN layers | `1-4` |
# | `dropout` | Dropout probability | `0.2–0.5` |
# | `num_classes` | Output classes (pain levels) | *from label set* |
#
# ---
#
# ### 🏋️ Training Hyperparameters
# | Parameter | Description | Default / Range |
# |------------|--------------|-----------------|
# | `batch_size` | Samples per batch | `512/2^n` |
# | `learning_rate` | Optimizer learning rate | `1e-3` |
# | `num_epochs` | Training iterations | `500` |
# | `optimizer` | Optimization algorithm | `'AdamW'` |
# | `criterion` | Loss function | `CrossEntropyLoss()` |
# | `seed` | Random seed for reproducibility | `42` |
#
# ---
#
# ### 📤 Inference
# | Parameter | Description |
# |------------|--------------|
# | `LOAD_MODEL_PATH` | Path to pretrained `.pt` model (optional) |
# | `save_results` | Whether to write output CSV | `True` |
#
# ---
#
# > 💡 *Tip:* Adjust hyperparameters in the “Configuration” or “Training Setup” cell before running the notebook.

# %% [markdown]
# <a id="setup"></a>
# ## 1. Setup & Configuration
#
# *Optional: Connect to Google Drive (for Colab users)*

# %%
from google.colab import drive
drive.mount("/gdrive")
current_dir = "/gdrive/MyDrive/pirate_dataset"
# %cd $current_dir
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/pirate_dataset

# %% [markdown]
# *Set Model Type*

# %%
RNN_TYPE = 'LSTM'            # 'RNN', 'LSTM', or 'GRU'
BIDIRECTIONAL = True        # True / False

# %% [markdown]
# *Set Model Save Name*

# %%
from datetime import datetime

# Get current date and time for submission filename
current_datetime = datetime.now().strftime("%d-%m-%H-%M")

if BIDIRECTIONAL:
    EXPERIMENT_NAME = f"{RNN_TYPE}_bi_{current_datetime}"
else:
    EXPERIMENT_NAME = f"{RNN_TYPE}_{current_datetime}"

SUBMISSION_FILENAME = f"{EXPERIMENT_NAME}.csv"


# Directory configuration
logs_dir = "tensorboard"
models_dir = "models"

# Model save/load paths
MODEL_SAVE_PATH = f"{models_dir}/{EXPERIMENT_NAME}_model.pt"
MODEL_LOAD_PATH = f"{models_dir}/{EXPERIMENT_NAME}_model.pt"




print(f"Experiment name: {EXPERIMENT_NAME}")
print(f"Submission filename: {SUBMISSION_FILENAME}")
print(f"Model save path: {MODEL_SAVE_PATH}")
print(f"Model load path: {MODEL_LOAD_PATH}")
# Out:
# Experiment name: LSTM_bi_11-11-00-21
# Submission filename: LSTM_bi_11-11-00-21.csv
# Model save path: models/LSTM_bi_11-11-00-21_model.pt
# Model load path: models/LSTM_bi_11-11-00-21_model.pt

# %% [markdown]
# <a id="data-loading"></a>
# ## 2. Data Loading
#
# Load training and test datasets from CSV files.

# %%
import pandas as pd

X_train = pd.read_csv('pirate_pain_train.csv')
y_train = pd.read_csv('pirate_pain_train_labels.csv')

# %% [markdown]
# <a id="import-libraries"></a>
# ## 3. Import Libraries
#
# Set random seeds for reproducibility and import all necessary packages.

# %%
# Set seed for reproducibility
SEED = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import TensorDataset, DataLoader
from collections import Counter






# !pkill -f tensorboard
# %load_ext tensorboard
# !mkdir -p {models_dir}

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import copy
import shutil
from datetime import datetime
from itertools import product
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# PyTorch version: 2.8.0+cu126
# Device: cuda

# %% [markdown]
# <a id="data-preprocessing"></a>
# ## 4. Data Preprocessing
#
# Explore data, split into train/val/test sets, normalize features, and encode labels.

# %% [markdown]
# ### 4.1 Data Exploration

# %%
# Print the shape of the dataset
print(f"Dataset shape: {X_train.shape}")

# Display the first few rows of the dataset
X_train.head(10)
# Out:
# Dataset shape: (105760, 40)
#    sample_index  time  pain_survey_1  pain_survey_2  pain_survey_3  \
# 0             0     0              2              0              2
# 1             0     1              2              2              2
# 2             0     2              2              0              2
# 3             0     3              2              2              2
# 4             0     4              2              2              2
# 5             0     5              2              0              2
# 6             0     6              2              1              2
# 7             0     7              2              2              2
# 8             0     8              2              2              0
# 9             0     9              0              2              2
#
#    pain_survey_4 n_legs n_hands n_eyes  joint_00  ...      joint_21  \
# 0              1    two     two    two  1.094705  ...  3.499558e-06
# 1              2    two     two    two  1.135183  ...  3.976952e-07
# 2              2    two     two    two  1.080745  ...  1.533820e-07
# 3              2    two     two    two  0.938017  ...  1.006865e-05
# 4              2    two     two    two  1.090185  ...  4.437266e-06
# 5              1    two     two    two  1.146031  ...  1.073167e-06
# 6              1    two     two    two  1.025870  ...  1.074800e-06
# 7              2    two     two    two  1.038597  ...  8.829074e-07
# 8              1    two     two    two  0.984251  ...  1.621055e-06
# 9              2    two     two    two  1.054999  ...  1.609114e-06
#
#        joint_22      joint_23      joint_24  joint_25  joint_26  joint_27  \
# 0  1.945042e-06  3.999558e-06  1.153299e-05  0.000004  0.017592  0.013508
# 1  6.765107e-07  6.019627e-06  4.643774e-08  0.000000  0.013352  0.000000
# 2  1.698525e-07  1.446051e-06  2.424536e-06  0.000003  0.016225  0.008110
# 3  5.511079e-07  1.847597e-06  5.432416e-08  0.000000  0.011832  0.007450
# 4  1.735459e-07  1.552722e-06  5.825366e-08  0.000007  0.005360  0.002532
# 5  1.753837e-07  2.957340e-07  6.217311e-08  0.000007  0.006150  0.006444
# 6  1.772156e-07  1.976558e-06  1.576086e-06  0.000005  0.006495  0.006421
# 7  1.790415e-07  2.210562e-06  1.485741e-06  0.000000  0.015998  0.005397
# 8  1.165161e-06  3.030164e-07  5.416678e-07  0.000000  0.020539  0.008517
# 9  3.959558e-06  2.017157e-06  1.154349e-06  0.000007  0.007682  0.021383
#
#    joint_28  joint_29  joint_30
# 0  0.026798  0.027815       0.5
# 1  0.013377  0.013716       0.5
# 2  0.024097  0.023105       0.5
# 3  0.028613  0.024648       0.5
# 4  0.033026  0.025328       0.5
# 5  0.033101  0.023767       0.5
# 6  0.031804  0.019056       0.5
# 7  0.035552  0.015732       0.5
# 8  0.008635  0.015257       0.5
# 9  0.034006  0.028966       0.5
#
# [10 rows x 40 columns]

# %% [markdown]
# ### 4.2 Categorical Encoding

# %%
# Merge features and labels
data = X_train.merge(y_train, on='sample_index')

# Create a mapping dictionary to convert categorical labels to numerical values
map_dict = {'none': 0, 'one': 1, 'two': 2}
data['n_legs'] = data['n_legs'].map(map_dict)
data['n_hands'] = data['n_hands'].map(map_dict)
data['n_eyes'] = data['n_eyes'].map(map_dict)

# %% [markdown]
# ### 4.3 Stratified Train/Val/Test Split

# %%
import pandas as pd
import random
from sklearn.model_selection import train_test_split

# df has columns: ['sample_index', 'label']
N_VAL_USERS = 60
N_TEST_USERS = 60

# --- Step 1: Compute each user's dominant label (or label distribution)
user_labels = (
    data.groupby('sample_index')['label']
    .agg(lambda x: x.value_counts().index[0])  # dominant label per user
    .reset_index()
)

train_users, temp_users = train_test_split(
    user_labels['sample_index'],
    test_size=(N_VAL_USERS + N_TEST_USERS) / len(user_labels),
    stratify=user_labels['label'],
    random_state=SEED
)

# Split temp into val/test (also stratified)
temp_labels = user_labels[user_labels['sample_index'].isin(temp_users)]
if N_TEST_USERS != 0:
  val_users, test_users = train_test_split(
      temp_labels['sample_index'],
      test_size=N_TEST_USERS / (N_VAL_USERS + N_TEST_USERS),
      stratify=temp_labels['label'],
      random_state=SEED
  )
else:
  val_users = temp_users
  test_users = []

# --- Step 3: Filter your main df
df_train = data[data['sample_index'].isin(train_users)]
df_val = data[data['sample_index'].isin(val_users)]
df_test = data[data['sample_index'].isin(test_users)]

# --- Step 4: Check label proportions
print("Label proportions:")
print("Train:\n", df_train['label'].value_counts(normalize=True))
print("Val:\n", df_val['label'].value_counts(normalize=True))
print("Test:\n", df_test['label'].value_counts(normalize=True))
# Out:
# Label proportions:
# Train:
#  label
# no_pain      0.772643
# low_pain     0.142329
# high_pain    0.085028
# Name: proportion, dtype: float64
# Val:
#  label
# no_pain      0.783333
# low_pain     0.133333
# high_pain    0.083333
# Name: proportion, dtype: float64
# Test:
#  label
# no_pain      0.766667
# low_pain     0.150000
# high_pain    0.083333
# Name: proportion, dtype: float64

# %%
df_train.shape, df_val.shape, df_test.shape
# Out:
# ((86560, 41), (9600, 41), (9600, 41))

# %%
# Print the total number of pirates for each dataset
print(f"Total pirates in training set: {df_train['sample_index'].nunique()}")
print(f"Total pirates in validation set: {df_val['sample_index'].nunique()}")
print(f"Total pirates in test set: {df_test['sample_index'].nunique()}")
# Out:
# Total pirates in training set: 541
# Total pirates in validation set: 60
# Total pirates in test set: 60

# %% [markdown]
# ### 4.4 Feature Normalization (min-max)

# %%
# Define the columns to be normalised

scale_columns = [col for col in data.columns
                 if (col.startswith('joint_') or col.startswith('pain_survey')) and not col.startswith('joint_30')]



# Calculate the minimum and maximum values from the training data only
mins_train = df_train[scale_columns].min()
maxs_train = df_train[scale_columns].max()

#mins_val = df_val[scale_columns].min()
#maxs_val = df_val[scale_columns].max()
#
#mins_test = df_test[scale_columns].min()
#maxs_test = df_test[scale_columns].max()

####
#CHANGED ALL THE REGULARIZATION TO USE MIN AND MAX VALUES FROM THE TRAINING DATA FOR GENERALIZATION
###

# Apply normalisation to the specified columns in all datasets
for column in scale_columns:
    # Normalise the training set
    df_train[column] = (df_train[column] - mins_train[column]) / (maxs_train[column] - mins_train[column])

    # Normalise the validation set
    df_val[column] = (df_val[column] - mins_train[column]) / (maxs_train[column] - mins_train[column])

    # Normalise the test set
    df_test[column] = (df_test[column] - mins_train[column]) / (maxs_train[column] - mins_train[column])

# %%
df_train.head()
# Out:
#    sample_index  time  pain_survey_1  pain_survey_2  pain_survey_3  \
# 0             0     0            1.0            0.0            1.0
# 1             0     1            1.0            1.0            1.0
# 2             0     2            1.0            0.0            1.0
# 3             0     3            1.0            1.0            1.0
# 4             0     4            1.0            1.0            1.0
#
#    pain_survey_4  n_legs  n_hands  n_eyes  joint_00  ...      joint_22  \
# 0            0.5     2.0      2.0     2.0  0.777046  ...  1.503263e-06
# 1            1.0     2.0      2.0     2.0  0.805855  ...  4.403064e-07
# 2            1.0     2.0      2.0     2.0  0.767110  ...  1.575589e-08
# 3            1.0     2.0      2.0     2.0  0.665528  ...  3.352260e-07
# 4            1.0     2.0      2.0     2.0  0.773829  ...  1.885071e-08
#
#    joint_23  joint_24  joint_25  joint_26  joint_27  joint_28  joint_29  \
# 0  0.000105  0.000405  0.000004  0.014214  0.011376  0.018978  0.020291
# 1  0.000158  0.000001  0.000000  0.010748  0.000000  0.009473  0.010006
# 2  0.000038  0.000085  0.000003  0.013097  0.006830  0.017065  0.016856
# 3  0.000049  0.000002  0.000000  0.009505  0.006274  0.020264  0.017981
# 4  0.000041  0.000002  0.000007  0.004216  0.002132  0.023389  0.018477
#
#    joint_30    label
# 0       0.5  no_pain
# 1       0.5  no_pain
# 2       0.5  no_pain
# 3       0.5  no_pain
# 4       0.5  no_pain
#
# [5 rows x 41 columns]

# %% [markdown]
# ### 4.5 Label Distribution Analysis

# %%
# Initialise a dictionary to count occurrences of each activity in the training set
training_labels = {
    'no_pain': 0,
    'low_pain': 0,
    'high_pain': 0
}

# Count occurrences of each activity for unique IDs in the training set
for id in df_train['sample_index'].unique():
    label = df_train[df_train['sample_index'] == id]['label'].values[0]
    training_labels[label] += 1


# Print the distribution of training labels
print('Training labels:', training_labels)

# Initialise a dictionary to count occurrences of each activity in the training set
val_labels = {
    'no_pain': 0,
    'low_pain': 0,
    'high_pain': 0
}

# Count occurrences of each activity for unique IDs in the training set
for id in df_val['sample_index'].unique():
    label = df_val[df_val['sample_index'] == id]['label'].values[0]
    val_labels[label] += 1

# Print the distribution of validation labels
print('Validation labels:', val_labels)

# Initialise a dictionary to count occurrences of each activity in the test set
test_labels = {
    'no_pain': 0,
    'low_pain': 0,
    'high_pain': 0
}

# Count occurrences of each activity for unique IDs in the test set
for id in df_test['sample_index'].unique():
    label = df_test[df_test['sample_index'] == id]['label'].values[0]
    test_labels[label] += 1

# Print the distribution of test labels
print('Test labels:', test_labels)
# Out:
# Training labels: {'no_pain': 418, 'low_pain': 77, 'high_pain': 46}
# Validation labels: {'no_pain': 47, 'low_pain': 8, 'high_pain': 5}
# Test labels: {'no_pain': 46, 'low_pain': 9, 'high_pain': 5}

# %%
# Define a training mapping of label names to integer labels
label_mapping = {
    'no_pain': 0,
    'low_pain': 1,
    'high_pain': 2
}

# Map label names to integers in the training set
df_train['label'] = df_train['label'].map(label_mapping)

# Map label names to integers in the validation set
df_val['label'] = df_val['label'].map(label_mapping)

# Map label names to integers in the test set
df_test['label'] = df_test['label'].map(label_mapping)

# %% [markdown]
# <a id="sequence-building"></a>
# ## 5. Sequence Building
#
# Convert variable-length time-series into fixed-size windows for RNN input.

# %%
# Define window and stride boolean variable -> if True, during training we will visit more time the same pirate with overlapping windows
# if False, each pirate will be visited only once during training
one_pirate_window = True

# %%
if one_pirate_window:
    # Define the window size
    WINDOW_SIZE = 80 # before: 80

    # Stride size
    STRIDE = 40
else:
    # Define the window size -> select an higher window size in order to get more pirates
    WINDOW_SIZE = 160

    # Stride size
    STRIDE = 160

# %% [markdown]
# ### 5.1 Window & Stride Configuration

# %% [markdown]
# ### 5.2 Build Sequences Function

# %%
def build_sequences(df, window=200, stride=200):
    assert window % stride == 0

    dataset = []
    labels = []
    ids = []  # <--- NEW: to store pirate/sample IDs

    for id in df['sample_index'].unique():
        columns = [col for col in df.columns if col not in ['sample_index', 'label', 'time']]
        temp = df[df['sample_index'] == id][columns].values
        label = df[df['sample_index'] == id]['label'].values[0]

        padding_len = window - len(temp) % window
        padding = np.zeros((padding_len, len(columns)), dtype='float32')
        temp = np.concatenate((temp, padding))

        idx = 0
        while idx + window <= len(temp):
            dataset.append(temp[idx:idx + window])
            labels.append(label)
            ids.append(id)  # <--- NEW: add same ID for each window
            idx += stride

    dataset = np.array(dataset)
    labels = np.array(labels)
    ids = np.array(ids)  # <--- convert to numpy

    return dataset, labels, ids  # <--- UPDATED return

# %% [markdown]
# ### 5.3 Generate Sequences for Train/Val/Test

# %%
# Generate sequences and labels for the training set
X_train, y_train, ids_train = build_sequences(df_train, WINDOW_SIZE, STRIDE)

# Generate sequences and labels for the validation set
X_val, y_val, ids_val = build_sequences(df_val, WINDOW_SIZE, STRIDE)

# Generate sequences and labels for the test set
X_test, y_test, ids_test = build_sequences(df_test, WINDOW_SIZE, STRIDE)

# Print the shapes of the generated datasets and their labels
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (2705, 80, 38), y_train shape: (2705,)
# X_val shape: (300, 80, 38), y_val shape: (300,)
# X_test shape: (300, 80, 38), y_test shape: (300,)

# %% [markdown]
# ### 5.4 Data Type Conversion & Cleaning

# %%
# Convert dataset into float32 for PyTorch compatibility
X_train = X_train.astype('float32')
X_val = X_val.astype('float32')
X_test = X_test.astype('float32')
# y_train = y_train.astype('int64')
# y_val = y_val.astype('int64')
# y_test = y_test.astype('int64')

# %%
# Define the input shape based on the training data
input_shape = X_train.shape[1:]

# Define the number of classes based on the categorical labels
num_classes = len(np.unique(y_train))
print(f"Number of Classes: {num_classes}")
# Out:
# Number of Classes: 3

# %%
# Discard nan values from the dataset
if np.isnan(X_train).any() or np.isnan(X_val).any() or np.isnan(X_test).any():
    X_train = np.nan_to_num(X_train)
    X_val = np.nan_to_num(X_val)
    X_test = np.nan_to_num(X_test)

# %%
# Convert numpy arrays to PyTorch datasets (pairs features with labels)
train_ds = TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train))
val_ds   = TensorDataset(torch.from_numpy(X_val), torch.from_numpy(y_val))
test_ds  = TensorDataset(torch.from_numpy(X_test), torch.from_numpy(y_test))

# %% [markdown]
# <a id="dataloaders"></a>
# ## 6. DataLoaders
#
# Create PyTorch DataLoaders for efficient batching and parallel loading.

# %%
# Define the batch size, which is the number of samples in each batch
BATCH_SIZE = 512 # we can change it depending on the GPU RAM available (by default 512)

# %%
def make_loader(ds, batch_size, shuffle, drop_last):
    # Determine optimal number of worker processes for data loading
    cpu_cores = os.cpu_count() or 2
    num_workers = max(2, min(4, cpu_cores))

    # Create DataLoader with performance optimizations
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,  # Faster GPU transfer
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=4,  # Load 4 batches ahead
    )

# %%
# Create data loaders with different settings for each phase
train_loader = make_loader(train_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
val_loader   = make_loader(val_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
test_loader  = make_loader(test_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

# %%
# Get one batch from the training data loader
for xb, yb in train_loader:
    print("Features batch shape:", xb.shape)
    print("Labels batch shape:", yb.shape)
    break # Stop after getting one batch
# Out:
# Features batch shape: torch.Size([512, 80, 38])
# Labels batch shape: torch.Size([512])

# %%
def recurrent_summary(model, input_size):
    """
    Custom summary function that emulates torchinfo's output while correctly
    counting parameters for RNN/GRU/LSTM layers.

    This function is designed for models whose direct children are
    nn.Linear, nn.RNN, nn.GRU, or nn.LSTM layers.

    Args:
        model (nn.Module): The model to analyze.
        input_size (tuple): Shape of the input tensor (e.g., (seq_len, features)).
    """

    # Dictionary to store output shapes captured by forward hooks
    output_shapes = {}
    # List to track hook handles for later removal
    hooks = []

    def get_hook(name):
        """Factory function to create a forward hook for a specific module."""
        def hook(module, input, output):
            # Handle RNN layer outputs (returns a tuple)
            if isinstance(output, tuple):
                # output[0]: all hidden states with shape (batch, seq_len, hidden*directions)
                shape1 = list(output[0].shape)
                shape1[0] = -1  # Replace batch dimension with -1

                # output[1]: final hidden state h_n (or tuple (h_n, c_n) for LSTM)
                if isinstance(output[1], tuple):  # LSTM case: (h_n, c_n)
                    shape2 = list(output[1][0].shape)  # Extract h_n only
                else:  # RNN/GRU case: h_n only
                    shape2 = list(output[1].shape)

                # Replace batch dimension (middle position) with -1
                shape2[1] = -1

                output_shapes[name] = f"[{shape1}, {shape2}]"

            # Handle standard layer outputs (e.g., Linear)
            else:
                shape = list(output.shape)
                shape[0] = -1  # Replace batch dimension with -1
                output_shapes[name] = f"{shape}"
        return hook

    # 1. Determine the device where model parameters reside
    try:
        device = next(model.parameters()).device
    except StopIteration:
        device = torch.device("cpu")  # Fallback for models without parameters

    # 2. Create a dummy input tensor with batch_size=1
    dummy_input = torch.randn(1, *input_size).to(device)

    # 3. Register forward hooks on target layers
    # Iterate through direct children of the model (e.g., self.rnn, self.classifier)
    for name, module in model.named_children():
        if isinstance(module, (nn.Linear, nn.RNN, nn.GRU, nn.LSTM)):
            # Register the hook and store its handle for cleanup
            hook_handle = module.register_forward_hook(get_hook(name))
            hooks.append(hook_handle)

    # 4. Execute a dummy forward pass in evaluation mode
    model.eval()
    with torch.no_grad():
        try:
            model(dummy_input)
        except Exception as e:
            print(f"Error during dummy forward pass: {e}")
            # Clean up hooks even if an error occurs
            for h in hooks:
                h.remove()
            return

    # 5. Remove all registered hooks
    for h in hooks:
        h.remove()

    # --- 6. Print the summary table ---

    print("-" * 79)
    # Column headers
    print(f"{'Layer (type)':<25} {'Output Shape':<28} {'Param #':<18}")
    print("=" * 79)

    total_params = 0
    total_trainable_params = 0

    # Iterate through modules again to collect and display parameter information
    for name, module in model.named_children():
        if name in output_shapes:
            # Count total and trainable parameters for this module
            module_params = sum(p.numel() for p in module.parameters())
            trainable_params = sum(p.numel() for p in module.parameters() if p.requires_grad)

            total_params += module_params
            total_trainable_params += trainable_params

            # Format strings for display
            layer_name = f"{name} ({type(module).__name__})"
            output_shape_str = str(output_shapes[name])
            params_str = f"{trainable_params:,}"

            print(f"{layer_name:<25} {output_shape_str:<28} {params_str:<15}")

    print("=" * 79)
    print(f"Total params: {total_params:,}")
    print(f"Trainable params: {total_trainable_params:,}")
    print(f"Non-trainable params: {total_params - total_trainable_params:,}")
    print("-" * 79)

# %% [markdown]
# <a id="hyperparameters"></a>
# ## 7. Network Hyperparameters
#
# Configure training settings, architecture parameters, and regularization.

# %%
 # Training configuration
LEARNING_RATE = 1e-3
EPOCHS = 500
PATIENCE = 40

# Architecture
HIDDEN_LAYERS = 2        # Hidden layers
HIDDEN_SIZE = 46        # Neurons per layer -> prev hidden size = 128

# Regularisation
DROPOUT_RATE = 0.3     # Dropout probability

# For now disable weight decay
L1_LAMBDA = 0.0001         # L1 penalty
L2_LAMBDA = 0.001            # L2 penalty

# Set up loss function and optimizer
weights = torch.tensor([0.5, 1.0, 1.2]).to(device)# Not used

criterion = nn.CrossEntropyLoss(weight=weights)

# %%
# Initialize best model tracking variables
best_model = None
best_performance = float('-inf')

# %% [markdown]
# <a id="model-architecture"></a>
# ## 8. Model Architecture
#
# Custom RNN/LSTM/GRU classifier with configurable bidirectionality and dropout.

# %% [markdown]
# ### 7.1 Recurrent Classifier Class

# %%
class RecurrentClassifier(nn.Module):
    """
    Generic RNN classifier (RNN, LSTM, GRU).
    Uses the last hidden state for classification.
    """
    def __init__(
            self,
            input_size,
            hidden_size,
            num_layers,
            num_classes,
            rnn_type= RNN_TYPE,        # 'RNN', 'LSTM', or 'GRU'
            bidirectional=BIDIRECTIONAL,
            dropout_rate=0.2
            ):
        super().__init__()

        self.rnn_type = rnn_type
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.bidirectional = bidirectional

        # Map string name to PyTorch RNN class
        rnn_map = {
            'RNN': nn.RNN,
            'LSTM': nn.LSTM,
            'GRU': nn.GRU
        }

        if rnn_type not in rnn_map:
            raise ValueError("rnn_type must be 'RNN', 'LSTM', or 'GRU'")

        rnn_module = rnn_map[rnn_type]

        # Dropout is only applied between layers (if num_layers > 1)
        dropout_val = dropout_rate if num_layers > 1 else 0 # dropout between RNN layers, applied for regularization

        # Create the recurrent layer
        self.rnn = rnn_module(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,       # Input shape: (batch, seq_len, features)
            bidirectional=bidirectional, # We are defining a bidirectional RNN since we want to extract also the future contextual information for making better predictions
            dropout=dropout_val
        )

        # Calculate input size for the final classifier
        if self.bidirectional:
            classifier_input_size = hidden_size * 2 # Concat fwd + bwd
        else:
            classifier_input_size = hidden_size

        # Final classification layer
        self.classifier = nn.Linear(classifier_input_size, num_classes) # output layer for classifying

    def forward(self, x):
        """
        x shape: (batch_size, seq_length, input_size)
        """

        # rnn_out shape: (batch_size, seq_len, hidden_size * num_directions)
        rnn_out, hidden = self.rnn(x) # feeds the input sequence into the RNN layer
        # rnn_out -> contains the hidden state output for every timestep

        # LSTM returns (h_n, c_n), we only need h_n
        if self.rnn_type == 'LSTM':
            hidden = hidden[0]  # final hidden state of the last timestep

        # hidden shape: (num_layers * num_directions, batch_size, hidden_size)

        if self.bidirectional:
            # Reshape to (num_layers, 2, batch_size, hidden_size)
            hidden = hidden.view(self.num_layers, 2, -1, self.hidden_size)

            # Concat last fwd (hidden[-1, 0, ...]) and bwd (hidden[-1, 1, ...])
            # Final shape: (batch_size, hidden_size * 2)
            hidden_to_classify = torch.cat([hidden[-1, 0, :, :], hidden[-1, 1, :, :]], dim=1)
        else:
            # Take the last layer's hidden state
            # Final shape: (batch_size, hidden_size)
            hidden_to_classify = hidden[-1]

        # Get logits
        logits = self.classifier(hidden_to_classify)
        return logits

# %% [markdown]
# <a id="training-functions"></a>
# ## 9. Training Functions
#
# Helper functions for training, validation, logging, and early stopping.

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0, l2_lambda=0):
    """
    Perform one complete training epoch through the entire training dataset.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): Lambda for L1 regularization
        l2_lambda (float): Lambda for L2 regularization

    Returns:
        tuple: (average_loss, f1 score) - Training loss and f1 score for this epoch
    """
    model.train()  # Set model to training mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Iterate through training batches
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move data to device (GPU/CPU)
        inputs, targets = inputs.to(device), targets.to(device)

        # Clear gradients from previous step
        optimizer.zero_grad(set_to_none=True)

        # Forward pass with mixed precision (if CUDA available)
        with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
            logits = model(inputs)
            loss = criterion(logits, targets)

            # Add L1 and L2 regularization
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm


        # Backward pass with gradient scaling
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Accumulate metrics
        running_loss += loss.item() * inputs.size(0)
        predictions = logits.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_f1

# %% [markdown]
# ### 9.1 Train One Epoch Function

# %%
def validate_one_epoch(model, val_loader, criterion, device):
    """
    Perform one complete validation epoch through the entire validation dataset.

    Args:
        model (nn.Module): The neural network model to evaluate (must be in eval mode)
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        criterion (nn.Module): Loss function used to calculate validation loss
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)

    Returns:
        tuple: (average_loss, accuracy) - Validation loss and accuracy for this epoch

    Note:
        This function automatically sets the model to evaluation mode and disables
        gradient computation for efficiency during validation.
    """
    model.eval()  # Set model to evaluation mode

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Disable gradient computation for validation
    with torch.no_grad():
        for inputs, targets in val_loader:
            # Move data to device
            inputs, targets = inputs.to(device), targets.to(device)

            # Forward pass with mixed precision (if CUDA available)
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                logits = model(inputs)
                loss = criterion(logits, targets)

            # Accumulate metrics
            running_loss += loss.item() * inputs.size(0)
            predictions = logits.argmax(dim=1)
            all_predictions.append(predictions.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_accuracy = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_accuracy

# %% [markdown]
# ### 9.2 Validate One Epoch Function

# %%
def log_metrics_to_tensorboard(writer, epoch, train_loss, train_f1, val_loss, val_f1, model):
    """
    Log training metrics and model parameters to TensorBoard for visualization.

    Args:
        writer (SummaryWriter): TensorBoard SummaryWriter object for logging
        epoch (int): Current epoch number (used as x-axis in TensorBoard plots)
        train_loss (float): Training loss for this epoch
        train_f1 (float): Training f1 score for this epoch
        val_loss (float): Validation loss for this epoch
        val_f1 (float): Validation f1 score for this epoch
        model (nn.Module): The neural network model (for logging weights/gradients)

    Note:
        This function logs scalar metrics (loss/f1 score) and histograms of model
        parameters and gradients, which helps monitor training progress and detect
        issues like vanishing/exploding gradients.
    """
    # Log scalar metrics
    writer.add_scalar('Loss/Training', train_loss, epoch)
    writer.add_scalar('Loss/Validation', val_loss, epoch)
    writer.add_scalar('F1/Training', train_f1, epoch)
    writer.add_scalar('F1/Validation', val_f1, epoch)

    # Log model parameters and gradients
    for name, param in model.named_parameters():
        if param.requires_grad:
            # Check if the tensor is not empty before adding a histogram
            if param.numel() > 0:
                writer.add_histogram(f'{name}/weights', param.data, epoch)
            if param.grad is not None:
                # Check if the gradient tensor is not empty before adding a histogram
                if param.grad.numel() > 0:
                    if param.grad is not None and torch.isfinite(param.grad).all():
                        writer.add_histogram(f'{name}/gradients', param.grad.data, epoch)

# %% [markdown]
# ### 9.3 Fit  Function

# %%
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, device,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name=""):
    """
    Train the neural network model on the training data and validate on the validation data.

    Args:
        model (nn.Module): The neural network model to train
        train_loader (DataLoader): PyTorch DataLoader containing training data batches
        val_loader (DataLoader): PyTorch DataLoader containing validation data batches
        epochs (int): Number of training epochs
        criterion (nn.Module): Loss function (e.g., CrossEntropyLoss, MSELoss)
        optimizer (torch.optim): Optimization algorithm (e.g., Adam, SGD)
        scaler (GradScaler): PyTorch's gradient scaler for mixed precision training
        device (torch.device): Computing device ('cuda' for GPU, 'cpu' for CPU)
        l1_lambda (float): L1 regularization coefficient (default: 0)
        l2_lambda (float): L2 regularization coefficient (default: 0)
        patience (int): Number of epochs to wait for improvement before early stopping (default: 0)
        evaluation_metric (str): Metric to monitor for early stopping (default: "val_f1")
        mode (str): 'max' for maximizing the metric, 'min' for minimizing (default: 'max')
        restore_best_weights (bool): Whether to restore model weights from best epoch (default: True)
        writer (SummaryWriter, optional): TensorBoard SummaryWriter object for logging (default: None)
        verbose (int, optional): Frequency of printing training progress (default: 10)
        experiment_name (str, optional): Experiment name for saving models (default: "")

    Returns:
        tuple: (model, training_history) - Trained model and metrics history
    """

    # Initialize metrics tracking
    training_history = {
        'train_loss': [], 'val_loss': [],
        'train_f1': [], 'val_f1': []
    }

    # Configure early stopping if patience is set
    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0

    print(f"Training {epochs} epochs...")

    # Main training loop: iterate through epochs
    for epoch in range(1, epochs + 1):

        # Forward pass through training data, compute gradients, update weights
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda, l2_lambda
        )

        # Evaluate model on validation data without updating weights
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        # Store metrics for plotting and analysis
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)

        # Write metrics to TensorBoard for visualization
        if writer is not None:
            log_metrics_to_tensorboard(
                writer, epoch, train_loss, train_f1, val_loss, val_f1, model
            )

        # Print progress every N epochs or on first epoch
        if verbose > 0:
            if epoch % verbose == 0 or epoch == 1:
                print(f"Epoch {epoch:3d}/{epochs} | "
                    f"Train: Loss={train_loss:.4f}, F1 Score={train_f1:.4f} | "
                    f"Val: Loss={val_loss:.4f}, F1 Score={val_f1:.4f}")

        # Early stopping logic: monitor metric and save best model
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode == 'max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                torch.save(model.state_dict(), MODEL_SAVE_PATH)
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    # Restore best model weights if early stopping was used
    if restore_best_weights and patience > 0:
        model.load_state_dict(torch.load(MODEL_SAVE_PATH))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric} {best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), MODEL_SAVE_PATH)

    # Close TensorBoard writer
    if writer is not None:
        writer.close()

    return model, training_history

# %% [markdown]
# ### 9.4 Training Loop

# %%
# %%time

# Create model and display architecture with parameter count
rnn_model = RecurrentClassifier(
    input_size=input_shape[-1], # Pass the number of features
    hidden_size=HIDDEN_SIZE,
    num_layers=HIDDEN_LAYERS,
    num_classes=num_classes,
    dropout_rate=DROPOUT_RATE,
    bidirectional=BIDIRECTIONAL,
    rnn_type=RNN_TYPE
    ).to(device)
recurrent_summary(rnn_model, input_size=input_shape)

# Set up TensorBoard logging and save model architecture
writer = SummaryWriter(f"./{logs_dir}/{EXPERIMENT_NAME}")
x = torch.randn(1, input_shape[0], input_shape[1]).to(device)
writer.add_graph(rnn_model, x)

# Define optimizer with L2 regularization
optimizer = torch.optim.AdamW(rnn_model.parameters(), lr=LEARNING_RATE, weight_decay=L2_LAMBDA)

# Enable mixed precision training for GPU acceleration
scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

# Train model and track training history
rnn_model, training_history = fit(
    model=rnn_model,
    train_loader=train_loader,
    val_loader=val_loader,
    l1_lambda=L1_LAMBDA,
    epochs=EPOCHS,
    criterion=criterion,
    optimizer=optimizer,
    scaler=scaler,
    device=device,
    writer=writer,
    verbose=1,
    experiment_name=EXPERIMENT_NAME,
    patience=PATIENCE
    )

# Update best model if current performance is superior
if training_history['val_f1'][-1] > best_performance:
    best_model = rnn_model
    best_performance = training_history['val_f1'][-1]
# Out:
# -------------------------------------------------------------------------------
# Layer (type)              Output Shape                 Param #
# ===============================================================================
# rnn (LSTM)                [[-1, 80, 64], [4, -1, 32]]  43,520
# classifier (Linear)       [-1, 3]                      195
# ===============================================================================
# Total params: 43,715
# Trainable params: 43,715
# Non-trainable params: 0
# -------------------------------------------------------------------------------
# Training 500 epochs...
# Epoch   1/500 | Train: Loss=1.4529, F1 Score=0.6020 | Val: Loss=1.0205, F1 Score=0.6882
# Epoch   2/500 | Train: Loss=1.3628, F1 Score=0.6735 | Val: Loss=0.9549, F1 Score=0.6882
# Epoch   3/500 | Train: Loss=1.3024, F1 Score=0.6735 | Val: Loss=0.9285, F1 Score=0.6882
# Epoch   4/500 | Train: Loss=1.2756, F1 Score=0.6735 | Val: Loss=0.9260, F1 Score=0.6882
# Epoch   5/500 | Train: Loss=1.2551, F1 Score=0.6735 | Val: Loss=0.9204, F1 Score=0.6882
# Epoch   6/500 | Train: Loss=1.2353, F1 Score=0.6735 | Val: Loss=0.9189, F1 Score=0.6882
# Epoch   7/500 | Train: Loss=1.2177, F1 Score=0.6735 | Val: Loss=0.9173, F1 Score=0.6882
# Epoch   8/500 | Train: Loss=1.2011, F1 Score=0.6735 | Val: Loss=0.9150, F1 Score=0.6882
# Epoch   9/500 | Train: Loss=1.1850, F1 Score=0.6735 | Val: Loss=0.9143, F1 Score=0.6882
# Epoch  10/500 | Train: Loss=1.1701, F1 Score=0.6735 | Val: Loss=0.9132, F1 Score=0.6882
# Epoch  11/500 | Train: Loss=1.1546, F1 Score=0.6735 | Val: Loss=0.9121, F1 Score=0.6882
# Epoch  12/500 | Train: Loss=1.1402, F1 Score=0.6735 | Val: Loss=0.9113, F1 Score=0.6882
# Epoch  13/500 | Train: Loss=1.1253, F1 Score=0.6735 | Val: Loss=0.9098, F1 Score=0.6882
# Epoch  14/500 | Train: Loss=1.1100, F1 Score=0.6735 | Val: Loss=0.9059, F1 Score=0.6882
# Epoch  15/500 | Train: Loss=1.0928, F1 Score=0.6735 | Val: Loss=0.9000, F1 Score=0.6882
# Epoch  16/500 | Train: Loss=1.0714, F1 Score=0.6735 | Val: Loss=0.8929, F1 Score=0.6882
# Epoch  17/500 | Train: Loss=1.0384, F1 Score=0.6756 | Val: Loss=0.9012, F1 Score=0.6882
# Epoch  18/500 | Train: Loss=1.0150, F1 Score=0.7010 | Val: Loss=0.8698, F1 Score=0.6878
# Epoch  19/500 | Train: Loss=0.9893, F1 Score=0.7159 | Val: Loss=0.8472, F1 Score=0.7019
# Epoch  20/500 | Train: Loss=0.9775, F1 Score=0.7146 | Val: Loss=0.8714, F1 Score=0.7426
# Epoch  21/500 | Train: Loss=0.9649, F1 Score=0.7330 | Val: Loss=0.8409, F1 Score=0.7317
# Epoch  22/500 | Train: Loss=0.9433, F1 Score=0.7475 | Val: Loss=0.8192, F1 Score=0.7569
# Epoch  23/500 | Train: Loss=0.9230, F1 Score=0.7643 | Val: Loss=0.8048, F1 Score=0.7705
# Epoch  24/500 | Train: Loss=0.9089, F1 Score=0.7661 | Val: Loss=0.8056, F1 Score=0.7777
# Epoch  25/500 | Train: Loss=0.9063, F1 Score=0.7711 | Val: Loss=0.7949, F1 Score=0.7837
# Epoch  26/500 | Train: Loss=0.8952, F1 Score=0.7669 | Val: Loss=0.7874, F1 Score=0.7901
# Epoch  27/500 | Train: Loss=0.8822, F1 Score=0.7710 | Val: Loss=0.7759, F1 Score=0.7991
# Epoch  28/500 | Train: Loss=0.8926, F1 Score=0.7652 | Val: Loss=0.7718, F1 Score=0.8055
# Epoch  29/500 | Train: Loss=0.8810, F1 Score=0.7679 | Val: Loss=0.7943, F1 Score=0.7945
# Epoch  30/500 | Train: Loss=0.8599, F1 Score=0.7757 | Val: Loss=0.7827, F1 Score=0.8041
# Epoch  31/500 | Train: Loss=0.8700, F1 Score=0.7722 | Val: Loss=0.7439, F1 Score=0.7958
# Epoch  32/500 | Train: Loss=0.8595, F1 Score=0.7743 | Val: Loss=0.7496, F1 Score=0.8040
# Epoch  33/500 | Train: Loss=0.8423, F1 Score=0.7782 | Val: Loss=0.7834, F1 Score=0.8053
# Epoch  34/500 | Train: Loss=0.8443, F1 Score=0.7841 | Val: Loss=0.7355, F1 Score=0.7968
# Epoch  35/500 | Train: Loss=0.8286, F1 Score=0.7845 | Val: Loss=0.7257, F1 Score=0.7960
# Epoch  36/500 | Train: Loss=0.8227, F1 Score=0.7885 | Val: Loss=0.7214, F1 Score=0.8002
# Epoch  37/500 | Train: Loss=0.8169, F1 Score=0.7854 | Val: Loss=0.7450, F1 Score=0.8055
# Epoch  38/500 | Train: Loss=0.8210, F1 Score=0.7855 | Val: Loss=0.7036, F1 Score=0.8178
# Epoch  39/500 | Train: Loss=0.8051, F1 Score=0.7960 | Val: Loss=0.6725, F1 Score=0.8226
# Epoch  40/500 | Train: Loss=0.8074, F1 Score=0.7967 | Val: Loss=0.6846, F1 Score=0.8392
# Epoch  41/500 | Train: Loss=0.7833, F1 Score=0.8014 | Val: Loss=0.6960, F1 Score=0.8092
# Epoch  42/500 | Train: Loss=0.7828, F1 Score=0.7943 | Val: Loss=0.6701, F1 Score=0.8385
# Epoch  43/500 | Train: Loss=0.7698, F1 Score=0.7983 | Val: Loss=0.6453, F1 Score=0.8356
# Epoch  44/500 | Train: Loss=0.7696, F1 Score=0.8003 | Val: Loss=0.7012, F1 Score=0.8122
# Epoch  45/500 | Train: Loss=0.7694, F1 Score=0.7952 | Val: Loss=0.6497, F1 Score=0.8264
# Epoch  46/500 | Train: Loss=0.7567, F1 Score=0.8020 | Val: Loss=0.6623, F1 Score=0.8331
# Epoch  47/500 | Train: Loss=0.7413, F1 Score=0.8102 | Val: Loss=0.6566, F1 Score=0.8331
# Epoch  48/500 | Train: Loss=0.7363, F1 Score=0.8090 | Val: Loss=0.6599, F1 Score=0.8278
# Epoch  49/500 | Train: Loss=0.7384, F1 Score=0.8059 | Val: Loss=0.6619, F1 Score=0.8466
# Epoch  50/500 | Train: Loss=0.7392, F1 Score=0.8061 | Val: Loss=0.6931, F1 Score=0.8294
# Epoch  51/500 | Train: Loss=0.7377, F1 Score=0.8168 | Val: Loss=0.6574, F1 Score=0.8373
# Epoch  52/500 | Train: Loss=0.7367, F1 Score=0.8068 | Val: Loss=0.6791, F1 Score=0.8382
# Epoch  53/500 | Train: Loss=0.7187, F1 Score=0.8136 | Val: Loss=0.6875, F1 Score=0.8398
# Epoch  54/500 | Train: Loss=0.7149, F1 Score=0.8217 | Val: Loss=0.6793, F1 Score=0.8450
# Epoch  55/500 | Train: Loss=0.7161, F1 Score=0.8184 | Val: Loss=0.6654, F1 Score=0.8478
# Epoch  56/500 | Train: Loss=0.6981, F1 Score=0.8227 | Val: Loss=0.7238, F1 Score=0.8299
# Epoch  57/500 | Train: Loss=0.7162, F1 Score=0.8144 | Val: Loss=0.6613, F1 Score=0.8375
# Epoch  58/500 | Train: Loss=0.7074, F1 Score=0.8170 | Val: Loss=0.6490, F1 Score=0.8485
# Epoch  59/500 | Train: Loss=0.7179, F1 Score=0.8114 | Val: Loss=0.6570, F1 Score=0.8543
# Epoch  60/500 | Train: Loss=0.6949, F1 Score=0.8199 | Val: Loss=0.6541, F1 Score=0.8436
# Epoch  61/500 | Train: Loss=0.6916, F1 Score=0.8190 | Val: Loss=0.6701, F1 Score=0.8507
# Epoch  62/500 | Train: Loss=0.7007, F1 Score=0.8120 | Val: Loss=0.7549, F1 Score=0.8247
# Epoch  63/500 | Train: Loss=0.7130, F1 Score=0.8171 | Val: Loss=0.6422, F1 Score=0.8305
# Epoch  64/500 | Train: Loss=0.6961, F1 Score=0.8159 | Val: Loss=0.6597, F1 Score=0.8268
# Epoch  65/500 | Train: Loss=0.6810, F1 Score=0.8128 | Val: Loss=0.6511, F1 Score=0.8483
# Epoch  66/500 | Train: Loss=0.6662, F1 Score=0.8290 | Val: Loss=0.6651, F1 Score=0.8540
# Epoch  67/500 | Train: Loss=0.6800, F1 Score=0.8240 | Val: Loss=0.7087, F1 Score=0.8408
# Epoch  68/500 | Train: Loss=0.6774, F1 Score=0.8310 | Val: Loss=0.6771, F1 Score=0.8469
# Epoch  69/500 | Train: Loss=0.6742, F1 Score=0.8301 | Val: Loss=0.6849, F1 Score=0.8473
# Epoch  70/500 | Train: Loss=0.6694, F1 Score=0.8368 | Val: Loss=0.6659, F1 Score=0.8473
# Epoch  71/500 | Train: Loss=0.6806, F1 Score=0.8246 | Val: Loss=0.6810, F1 Score=0.8486
# Epoch  72/500 | Train: Loss=0.6982, F1 Score=0.8268 | Val: Loss=0.6466, F1 Score=0.8310
# Epoch  73/500 | Train: Loss=0.6681, F1 Score=0.8321 | Val: Loss=0.6853, F1 Score=0.8459
# Epoch  74/500 | Train: Loss=0.6609, F1 Score=0.8411 | Val: Loss=0.7038, F1 Score=0.8439
# Epoch  75/500 | Train: Loss=0.6468, F1 Score=0.8463 | Val: Loss=0.7061, F1 Score=0.8481
# Epoch  76/500 | Train: Loss=0.6467, F1 Score=0.8556 | Val: Loss=0.6890, F1 Score=0.8274
# Epoch  77/500 | Train: Loss=0.6695, F1 Score=0.8447 | Val: Loss=0.6463, F1 Score=0.8524
# Epoch  78/500 | Train: Loss=0.6491, F1 Score=0.8462 | Val: Loss=0.6506, F1 Score=0.8528
# Epoch  79/500 | Train: Loss=0.6325, F1 Score=0.8542 | Val: Loss=0.6432, F1 Score=0.8464
# Epoch  80/500 | Train: Loss=0.6505, F1 Score=0.8463 | Val: Loss=0.6928, F1 Score=0.8385
# Epoch  81/500 | Train: Loss=0.6566, F1 Score=0.8459 | Val: Loss=0.6472, F1 Score=0.8472
# Epoch  82/500 | Train: Loss=0.6498, F1 Score=0.8480 | Val: Loss=0.6548, F1 Score=0.8419
# Epoch  83/500 | Train: Loss=0.6344, F1 Score=0.8563 | Val: Loss=0.6619, F1 Score=0.8469
# Epoch  84/500 | Train: Loss=0.6339, F1 Score=0.8595 | Val: Loss=0.6849, F1 Score=0.8496
# Epoch  85/500 | Train: Loss=0.6159, F1 Score=0.8637 | Val: Loss=0.6525, F1 Score=0.8552
# Epoch  86/500 | Train: Loss=0.6072, F1 Score=0.8691 | Val: Loss=0.6306, F1 Score=0.8521
# Epoch  87/500 | Train: Loss=0.5948, F1 Score=0.8712 | Val: Loss=0.6721, F1 Score=0.8469
# Epoch  88/500 | Train: Loss=0.6058, F1 Score=0.8648 | Val: Loss=0.6414, F1 Score=0.8451
# Epoch  89/500 | Train: Loss=0.6038, F1 Score=0.8643 | Val: Loss=0.7007, F1 Score=0.8369
# Epoch  90/500 | Train: Loss=0.5996, F1 Score=0.8608 | Val: Loss=0.6982, F1 Score=0.8480
# Epoch  91/500 | Train: Loss=0.5916, F1 Score=0.8701 | Val: Loss=0.6452, F1 Score=0.8391
# Epoch  92/500 | Train: Loss=0.5882, F1 Score=0.8659 | Val: Loss=0.6556, F1 Score=0.8452
# Epoch  93/500 | Train: Loss=0.5997, F1 Score=0.8687 | Val: Loss=0.6614, F1 Score=0.8403
# Epoch  94/500 | Train: Loss=0.6227, F1 Score=0.8626 | Val: Loss=0.6269, F1 Score=0.8247
# Epoch  95/500 | Train: Loss=0.6122, F1 Score=0.8613 | Val: Loss=0.6589, F1 Score=0.8377
# Epoch  96/500 | Train: Loss=0.5971, F1 Score=0.8684 | Val: Loss=0.6514, F1 Score=0.8469
# Epoch  97/500 | Train: Loss=0.5940, F1 Score=0.8678 | Val: Loss=0.6140, F1 Score=0.8484
# Epoch  98/500 | Train: Loss=0.5817, F1 Score=0.8710 | Val: Loss=0.6434, F1 Score=0.8403
# Epoch  99/500 | Train: Loss=0.5807, F1 Score=0.8735 | Val: Loss=0.6005, F1 Score=0.8279
# Epoch 100/500 | Train: Loss=0.5993, F1 Score=0.8614 | Val: Loss=0.6753, F1 Score=0.8151
# Epoch 101/500 | Train: Loss=0.5910, F1 Score=0.8625 | Val: Loss=0.6689, F1 Score=0.8514
# Epoch 102/500 | Train: Loss=0.5993, F1 Score=0.8684 | Val: Loss=0.6145, F1 Score=0.8443
# Epoch 103/500 | Train: Loss=0.6281, F1 Score=0.8527 | Val: Loss=0.6077, F1 Score=0.8493
# Epoch 104/500 | Train: Loss=0.5932, F1 Score=0.8668 | Val: Loss=0.6194, F1 Score=0.8436
# Epoch 105/500 | Train: Loss=0.5814, F1 Score=0.8726 | Val: Loss=0.6579, F1 Score=0.8457
# Epoch 106/500 | Train: Loss=0.5782, F1 Score=0.8686 | Val: Loss=0.6350, F1 Score=0.8574
# Epoch 107/500 | Train: Loss=0.5542, F1 Score=0.8798 | Val: Loss=0.6226, F1 Score=0.8423
# Epoch 108/500 | Train: Loss=0.5974, F1 Score=0.8592 | Val: Loss=0.6614, F1 Score=0.8578
# Epoch 109/500 | Train: Loss=0.6069, F1 Score=0.8572 | Val: Loss=0.7408, F1 Score=0.8126
# Epoch 110/500 | Train: Loss=0.7015, F1 Score=0.8173 | Val: Loss=0.6740, F1 Score=0.8283
# Epoch 111/500 | Train: Loss=0.6362, F1 Score=0.8518 | Val: Loss=0.6419, F1 Score=0.8330
# Epoch 112/500 | Train: Loss=0.5890, F1 Score=0.8680 | Val: Loss=0.6569, F1 Score=0.8462
# Epoch 113/500 | Train: Loss=0.5767, F1 Score=0.8755 | Val: Loss=0.6263, F1 Score=0.8338
# Epoch 114/500 | Train: Loss=0.5617, F1 Score=0.8709 | Val: Loss=0.6265, F1 Score=0.8449
# Epoch 115/500 | Train: Loss=0.5669, F1 Score=0.8773 | Val: Loss=0.6196, F1 Score=0.8395
# Epoch 116/500 | Train: Loss=0.5402, F1 Score=0.8833 | Val: Loss=0.6000, F1 Score=0.8419
# Epoch 117/500 | Train: Loss=0.5343, F1 Score=0.8861 | Val: Loss=0.5650, F1 Score=0.8447
# Epoch 118/500 | Train: Loss=0.5376, F1 Score=0.8811 | Val: Loss=0.6223, F1 Score=0.8287
# Epoch 119/500 | Train: Loss=0.5521, F1 Score=0.8728 | Val: Loss=0.6699, F1 Score=0.8426
# Epoch 120/500 | Train: Loss=0.5654, F1 Score=0.8748 | Val: Loss=0.5486, F1 Score=0.8520
# Epoch 121/500 | Train: Loss=0.5867, F1 Score=0.8661 | Val: Loss=0.5782, F1 Score=0.8395
# Epoch 122/500 | Train: Loss=0.5904, F1 Score=0.8660 | Val: Loss=0.5688, F1 Score=0.8258
# Epoch 123/500 | Train: Loss=0.5649, F1 Score=0.8755 | Val: Loss=0.5788, F1 Score=0.8488
# Epoch 124/500 | Train: Loss=0.5670, F1 Score=0.8682 | Val: Loss=0.6282, F1 Score=0.8478
# Epoch 125/500 | Train: Loss=0.5833, F1 Score=0.8715 | Val: Loss=0.6653, F1 Score=0.8122
# Epoch 126/500 | Train: Loss=0.5594, F1 Score=0.8773 | Val: Loss=0.6052, F1 Score=0.8460
# Epoch 127/500 | Train: Loss=0.5335, F1 Score=0.8784 | Val: Loss=0.5854, F1 Score=0.8472
# Epoch 128/500 | Train: Loss=0.5342, F1 Score=0.8824 | Val: Loss=0.5687, F1 Score=0.8608
# Epoch 129/500 | Train: Loss=0.5120, F1 Score=0.8898 | Val: Loss=0.5785, F1 Score=0.8478
# Epoch 130/500 | Train: Loss=0.5192, F1 Score=0.8857 | Val: Loss=0.5769, F1 Score=0.8408
# Epoch 131/500 | Train: Loss=0.5115, F1 Score=0.8872 | Val: Loss=0.6041, F1 Score=0.8478
# Epoch 132/500 | Train: Loss=0.5210, F1 Score=0.8870 | Val: Loss=0.5714, F1 Score=0.8615
# Epoch 133/500 | Train: Loss=0.5139, F1 Score=0.8876 | Val: Loss=0.6398, F1 Score=0.8285
# Epoch 134/500 | Train: Loss=0.5272, F1 Score=0.8805 | Val: Loss=0.6368, F1 Score=0.8298
# Epoch 135/500 | Train: Loss=0.5197, F1 Score=0.8795 | Val: Loss=0.6593, F1 Score=0.8247
# Epoch 136/500 | Train: Loss=0.5051, F1 Score=0.8891 | Val: Loss=0.6359, F1 Score=0.8473
# Epoch 137/500 | Train: Loss=0.5223, F1 Score=0.8824 | Val: Loss=0.5839, F1 Score=0.8514
# Epoch 138/500 | Train: Loss=0.6134, F1 Score=0.8747 | Val: Loss=0.6129, F1 Score=0.8378
# Epoch 139/500 | Train: Loss=0.5817, F1 Score=0.8748 | Val: Loss=0.5736, F1 Score=0.8385
# Epoch 140/500 | Train: Loss=0.5488, F1 Score=0.8728 | Val: Loss=0.5702, F1 Score=0.8386
# Epoch 141/500 | Train: Loss=0.5570, F1 Score=0.8718 | Val: Loss=0.6098, F1 Score=0.8386
# Epoch 142/500 | Train: Loss=0.5493, F1 Score=0.8706 | Val: Loss=0.6114, F1 Score=0.8467
# Epoch 143/500 | Train: Loss=0.5213, F1 Score=0.8868 | Val: Loss=0.5625, F1 Score=0.8612
# Epoch 144/500 | Train: Loss=0.4960, F1 Score=0.8949 | Val: Loss=0.5906, F1 Score=0.8514
# Epoch 145/500 | Train: Loss=0.4869, F1 Score=0.8941 | Val: Loss=0.5967, F1 Score=0.8432
# Epoch 146/500 | Train: Loss=0.5156, F1 Score=0.8877 | Val: Loss=0.5871, F1 Score=0.8379
# Epoch 147/500 | Train: Loss=0.5171, F1 Score=0.8804 | Val: Loss=0.6205, F1 Score=0.8478
# Epoch 148/500 | Train: Loss=0.5116, F1 Score=0.8873 | Val: Loss=0.6542, F1 Score=0.8463
# Epoch 149/500 | Train: Loss=0.5194, F1 Score=0.8877 | Val: Loss=0.5724, F1 Score=0.8560
# Epoch 150/500 | Train: Loss=0.4969, F1 Score=0.8900 | Val: Loss=0.5576, F1 Score=0.8698
# Epoch 151/500 | Train: Loss=0.5116, F1 Score=0.8833 | Val: Loss=0.6506, F1 Score=0.8395
# Epoch 152/500 | Train: Loss=0.5138, F1 Score=0.8884 | Val: Loss=0.6206, F1 Score=0.8489
# Epoch 153/500 | Train: Loss=0.5208, F1 Score=0.8860 | Val: Loss=0.6406, F1 Score=0.8412
# Epoch 154/500 | Train: Loss=0.5210, F1 Score=0.8864 | Val: Loss=0.6022, F1 Score=0.8514
# Epoch 155/500 | Train: Loss=0.4998, F1 Score=0.8909 | Val: Loss=0.5950, F1 Score=0.8490
# Epoch 156/500 | Train: Loss=0.4866, F1 Score=0.8934 | Val: Loss=0.6057, F1 Score=0.8514
# Epoch 157/500 | Train: Loss=0.4936, F1 Score=0.8900 | Val: Loss=0.6188, F1 Score=0.8468
# Epoch 158/500 | Train: Loss=0.5593, F1 Score=0.8777 | Val: Loss=0.6674, F1 Score=0.8484
# Epoch 159/500 | Train: Loss=0.5589, F1 Score=0.8814 | Val: Loss=0.6958, F1 Score=0.8467
# Epoch 160/500 | Train: Loss=0.5413, F1 Score=0.8820 | Val: Loss=0.7496, F1 Score=0.7953
# Epoch 161/500 | Train: Loss=0.5236, F1 Score=0.8869 | Val: Loss=0.6505, F1 Score=0.8461
# Epoch 162/500 | Train: Loss=0.5253, F1 Score=0.8824 | Val: Loss=0.7092, F1 Score=0.8074
# Epoch 163/500 | Train: Loss=0.5541, F1 Score=0.8769 | Val: Loss=0.6151, F1 Score=0.8464
# Epoch 164/500 | Train: Loss=0.5064, F1 Score=0.8891 | Val: Loss=0.6176, F1 Score=0.8495
# Epoch 165/500 | Train: Loss=0.5078, F1 Score=0.8906 | Val: Loss=0.5978, F1 Score=0.8552
# Epoch 166/500 | Train: Loss=0.4852, F1 Score=0.8941 | Val: Loss=0.6730, F1 Score=0.8463
# Epoch 167/500 | Train: Loss=0.4736, F1 Score=0.9009 | Val: Loss=0.6070, F1 Score=0.8489
# Epoch 168/500 | Train: Loss=0.5072, F1 Score=0.8919 | Val: Loss=0.5839, F1 Score=0.8579
# Epoch 169/500 | Train: Loss=0.5009, F1 Score=0.8881 | Val: Loss=0.6018, F1 Score=0.8603
# Epoch 170/500 | Train: Loss=0.4784, F1 Score=0.8946 | Val: Loss=0.5878, F1 Score=0.8700
# Epoch 171/500 | Train: Loss=0.4636, F1 Score=0.8986 | Val: Loss=0.6480, F1 Score=0.8438
# Epoch 172/500 | Train: Loss=0.4843, F1 Score=0.8939 | Val: Loss=0.6380, F1 Score=0.8633
# Epoch 173/500 | Train: Loss=0.5039, F1 Score=0.8897 | Val: Loss=0.6021, F1 Score=0.8329
# Epoch 174/500 | Train: Loss=0.4901, F1 Score=0.8934 | Val: Loss=0.7831, F1 Score=0.8514
# Epoch 175/500 | Train: Loss=0.5331, F1 Score=0.8889 | Val: Loss=0.6296, F1 Score=0.8514
# Epoch 176/500 | Train: Loss=0.5123, F1 Score=0.8845 | Val: Loss=0.6296, F1 Score=0.8453
# Epoch 177/500 | Train: Loss=0.4671, F1 Score=0.9004 | Val: Loss=0.6377, F1 Score=0.8452
# Epoch 178/500 | Train: Loss=0.4602, F1 Score=0.8998 | Val: Loss=0.5694, F1 Score=0.8554
# Epoch 179/500 | Train: Loss=0.4610, F1 Score=0.9008 | Val: Loss=0.5955, F1 Score=0.8551
# Epoch 180/500 | Train: Loss=0.4586, F1 Score=0.9022 | Val: Loss=0.6637, F1 Score=0.8303
# Epoch 181/500 | Train: Loss=0.4593, F1 Score=0.8964 | Val: Loss=0.6690, F1 Score=0.8439
# Epoch 182/500 | Train: Loss=0.4623, F1 Score=0.8999 | Val: Loss=0.6620, F1 Score=0.8374
# Epoch 183/500 | Train: Loss=0.5039, F1 Score=0.8881 | Val: Loss=0.6588, F1 Score=0.8473
# Epoch 184/500 | Train: Loss=0.4675, F1 Score=0.8966 | Val: Loss=0.6561, F1 Score=0.8452
# Epoch 185/500 | Train: Loss=0.4655, F1 Score=0.9001 | Val: Loss=0.6704, F1 Score=0.8412
# Epoch 186/500 | Train: Loss=0.4577, F1 Score=0.9003 | Val: Loss=0.6385, F1 Score=0.8504
# Epoch 187/500 | Train: Loss=0.4586, F1 Score=0.8994 | Val: Loss=0.6526, F1 Score=0.8464
# Epoch 188/500 | Train: Loss=0.4576, F1 Score=0.9040 | Val: Loss=0.6172, F1 Score=0.8489
# Epoch 189/500 | Train: Loss=0.4734, F1 Score=0.8954 | Val: Loss=0.5823, F1 Score=0.8501
# Epoch 190/500 | Train: Loss=0.4584, F1 Score=0.8982 | Val: Loss=0.6279, F1 Score=0.8581
# Epoch 191/500 | Train: Loss=0.4653, F1 Score=0.8921 | Val: Loss=0.6160, F1 Score=0.8452
# Epoch 192/500 | Train: Loss=0.4765, F1 Score=0.8988 | Val: Loss=0.6621, F1 Score=0.8492
# Epoch 193/500 | Train: Loss=0.4686, F1 Score=0.8946 | Val: Loss=0.7580, F1 Score=0.8125
# Epoch 194/500 | Train: Loss=0.5502, F1 Score=0.8749 | Val: Loss=0.6347, F1 Score=0.8641
# Epoch 195/500 | Train: Loss=0.4834, F1 Score=0.8924 | Val: Loss=0.6593, F1 Score=0.8534
# Epoch 196/500 | Train: Loss=0.4599, F1 Score=0.9000 | Val: Loss=0.6306, F1 Score=0.8411
# Epoch 197/500 | Train: Loss=0.4515, F1 Score=0.9015 | Val: Loss=0.5838, F1 Score=0.8549
# Epoch 198/500 | Train: Loss=0.4489, F1 Score=0.9071 | Val: Loss=0.6187, F1 Score=0.8499
# Epoch 199/500 | Train: Loss=0.4540, F1 Score=0.9002 | Val: Loss=0.6815, F1 Score=0.8504
# Epoch 200/500 | Train: Loss=0.4605, F1 Score=0.9027 | Val: Loss=0.6845, F1 Score=0.8236
# Epoch 201/500 | Train: Loss=0.4566, F1 Score=0.8995 | Val: Loss=0.7268, F1 Score=0.8503
# Epoch 202/500 | Train: Loss=0.4493, F1 Score=0.9024 | Val: Loss=0.6182, F1 Score=0.8463
# Epoch 203/500 | Train: Loss=0.4568, F1 Score=0.9071 | Val: Loss=0.6128, F1 Score=0.8514
# Epoch 204/500 | Train: Loss=0.4344, F1 Score=0.9077 | Val: Loss=0.6898, F1 Score=0.8514
# Epoch 205/500 | Train: Loss=0.4231, F1 Score=0.9087 | Val: Loss=0.6088, F1 Score=0.8457
# Epoch 206/500 | Train: Loss=0.4147, F1 Score=0.9139 | Val: Loss=0.6183, F1 Score=0.8535
# Epoch 207/500 | Train: Loss=0.4387, F1 Score=0.9072 | Val: Loss=0.6120, F1 Score=0.8679
# Epoch 208/500 | Train: Loss=0.4343, F1 Score=0.9023 | Val: Loss=0.6939, F1 Score=0.8415
# Epoch 209/500 | Train: Loss=0.4179, F1 Score=0.9104 | Val: Loss=0.6098, F1 Score=0.8731
# Epoch 210/500 | Train: Loss=0.4084, F1 Score=0.9146 | Val: Loss=0.6088, F1 Score=0.8787
# Epoch 211/500 | Train: Loss=0.4373, F1 Score=0.9063 | Val: Loss=0.6506, F1 Score=0.8593
# Epoch 212/500 | Train: Loss=0.4176, F1 Score=0.9092 | Val: Loss=0.7016, F1 Score=0.8464
# Epoch 213/500 | Train: Loss=0.4326, F1 Score=0.9083 | Val: Loss=0.6482, F1 Score=0.8612
# Epoch 214/500 | Train: Loss=0.4123, F1 Score=0.9130 | Val: Loss=0.6541, F1 Score=0.8535
# Epoch 215/500 | Train: Loss=0.4274, F1 Score=0.9073 | Val: Loss=0.6632, F1 Score=0.8398
# Epoch 216/500 | Train: Loss=0.4562, F1 Score=0.8942 | Val: Loss=0.7136, F1 Score=0.8390
# Epoch 217/500 | Train: Loss=0.4552, F1 Score=0.8987 | Val: Loss=0.6622, F1 Score=0.8421
# Epoch 218/500 | Train: Loss=0.4259, F1 Score=0.9116 | Val: Loss=0.6076, F1 Score=0.8489
# Epoch 219/500 | Train: Loss=0.4284, F1 Score=0.9097 | Val: Loss=0.6345, F1 Score=0.8670
# Epoch 220/500 | Train: Loss=0.4186, F1 Score=0.9123 | Val: Loss=0.7829, F1 Score=0.8065
# Epoch 221/500 | Train: Loss=0.5611, F1 Score=0.8657 | Val: Loss=0.7966, F1 Score=0.8347
# Epoch 222/500 | Train: Loss=0.5568, F1 Score=0.8741 | Val: Loss=0.8147, F1 Score=0.8383
# Epoch 223/500 | Train: Loss=0.6157, F1 Score=0.8664 | Val: Loss=0.7695, F1 Score=0.8264
# Epoch 224/500 | Train: Loss=0.5412, F1 Score=0.8756 | Val: Loss=0.6990, F1 Score=0.8299
# Epoch 225/500 | Train: Loss=0.4863, F1 Score=0.9009 | Val: Loss=0.6469, F1 Score=0.8509
# Epoch 226/500 | Train: Loss=0.4823, F1 Score=0.8971 | Val: Loss=0.5995, F1 Score=0.8584
# Epoch 227/500 | Train: Loss=0.4609, F1 Score=0.8999 | Val: Loss=0.6079, F1 Score=0.8580
# Epoch 228/500 | Train: Loss=0.4469, F1 Score=0.9086 | Val: Loss=0.6543, F1 Score=0.8615
# Epoch 229/500 | Train: Loss=0.4424, F1 Score=0.9059 | Val: Loss=0.6658, F1 Score=0.8514
# Epoch 230/500 | Train: Loss=0.4235, F1 Score=0.9114 | Val: Loss=0.6653, F1 Score=0.8514
# Epoch 231/500 | Train: Loss=0.4116, F1 Score=0.9139 | Val: Loss=0.6777, F1 Score=0.8489
# Epoch 232/500 | Train: Loss=0.4056, F1 Score=0.9137 | Val: Loss=0.6552, F1 Score=0.8489
# Epoch 233/500 | Train: Loss=0.4021, F1 Score=0.9149 | Val: Loss=0.6185, F1 Score=0.8514
# Epoch 234/500 | Train: Loss=0.4025, F1 Score=0.9162 | Val: Loss=0.7024, F1 Score=0.8444
# Epoch 235/500 | Train: Loss=0.3959, F1 Score=0.9168 | Val: Loss=0.6509, F1 Score=0.8648
# Epoch 236/500 | Train: Loss=0.4058, F1 Score=0.9144 | Val: Loss=0.6845, F1 Score=0.8457
# Epoch 237/500 | Train: Loss=0.3987, F1 Score=0.9131 | Val: Loss=0.6432, F1 Score=0.8597
# Epoch 238/500 | Train: Loss=0.3914, F1 Score=0.9155 | Val: Loss=0.6703, F1 Score=0.8514
# Epoch 239/500 | Train: Loss=0.3869, F1 Score=0.9164 | Val: Loss=0.6648, F1 Score=0.8493
# Epoch 240/500 | Train: Loss=0.4051, F1 Score=0.9130 | Val: Loss=0.6427, F1 Score=0.8622
# Epoch 241/500 | Train: Loss=0.4007, F1 Score=0.9127 | Val: Loss=0.6887, F1 Score=0.8534
# Epoch 242/500 | Train: Loss=0.3948, F1 Score=0.9158 | Val: Loss=0.7117, F1 Score=0.8540
# Epoch 243/500 | Train: Loss=0.4570, F1 Score=0.8943 | Val: Loss=0.7228, F1 Score=0.8503
# Epoch 244/500 | Train: Loss=0.4843, F1 Score=0.8937 | Val: Loss=0.6478, F1 Score=0.8700
# Epoch 245/500 | Train: Loss=0.4724, F1 Score=0.8932 | Val: Loss=0.6846, F1 Score=0.8290
# Epoch 246/500 | Train: Loss=0.5507, F1 Score=0.8745 | Val: Loss=0.7624, F1 Score=0.8458
# Epoch 247/500 | Train: Loss=0.4944, F1 Score=0.8793 | Val: Loss=0.6372, F1 Score=0.8760
# Epoch 248/500 | Train: Loss=0.4645, F1 Score=0.8985 | Val: Loss=0.6784, F1 Score=0.8558
# Epoch 249/500 | Train: Loss=0.4329, F1 Score=0.9089 | Val: Loss=0.6281, F1 Score=0.8819
# Epoch 250/500 | Train: Loss=0.4206, F1 Score=0.9105 | Val: Loss=0.6328, F1 Score=0.8699
# Epoch 251/500 | Train: Loss=0.3988, F1 Score=0.9190 | Val: Loss=0.6495, F1 Score=0.8580
# Epoch 252/500 | Train: Loss=0.3901, F1 Score=0.9176 | Val: Loss=0.6689, F1 Score=0.8514
# Epoch 253/500 | Train: Loss=0.3857, F1 Score=0.9189 | Val: Loss=0.6519, F1 Score=0.8580
# Epoch 254/500 | Train: Loss=0.3834, F1 Score=0.9180 | Val: Loss=0.6804, F1 Score=0.8549
# Epoch 255/500 | Train: Loss=0.3930, F1 Score=0.9148 | Val: Loss=0.6790, F1 Score=0.8651
# Epoch 256/500 | Train: Loss=0.3960, F1 Score=0.9169 | Val: Loss=0.6587, F1 Score=0.8644
# Epoch 257/500 | Train: Loss=0.3853, F1 Score=0.9156 | Val: Loss=0.6563, F1 Score=0.8493
# Epoch 258/500 | Train: Loss=0.3970, F1 Score=0.9157 | Val: Loss=0.6729, F1 Score=0.8704
# Epoch 259/500 | Train: Loss=0.3806, F1 Score=0.9169 | Val: Loss=0.6657, F1 Score=0.8593
# Epoch 260/500 | Train: Loss=0.3940, F1 Score=0.9106 | Val: Loss=0.7004, F1 Score=0.8634
# Epoch 261/500 | Train: Loss=0.3836, F1 Score=0.9193 | Val: Loss=0.6081, F1 Score=0.8597
# Epoch 262/500 | Train: Loss=0.3893, F1 Score=0.9139 | Val: Loss=0.7636, F1 Score=0.8634
# Epoch 263/500 | Train: Loss=0.4039, F1 Score=0.9120 | Val: Loss=0.6227, F1 Score=0.8551
# Epoch 264/500 | Train: Loss=0.4430, F1 Score=0.9027 | Val: Loss=0.6247, F1 Score=0.8579
# Epoch 265/500 | Train: Loss=0.4443, F1 Score=0.8990 | Val: Loss=0.7428, F1 Score=0.8494
# Epoch 266/500 | Train: Loss=0.4287, F1 Score=0.9075 | Val: Loss=0.6311, F1 Score=0.8581
# Epoch 267/500 | Train: Loss=0.4327, F1 Score=0.9043 | Val: Loss=0.9200, F1 Score=0.8030
# Epoch 268/500 | Train: Loss=0.5779, F1 Score=0.8711 | Val: Loss=0.7713, F1 Score=0.8193
# Epoch 269/500 | Train: Loss=0.5342, F1 Score=0.8783 | Val: Loss=0.7841, F1 Score=0.8517
# Epoch 270/500 | Train: Loss=0.5156, F1 Score=0.8908 | Val: Loss=0.7143, F1 Score=0.8639
# Epoch 271/500 | Train: Loss=0.4743, F1 Score=0.8976 | Val: Loss=0.7883, F1 Score=0.7983
# Epoch 272/500 | Train: Loss=0.6755, F1 Score=0.8195 | Val: Loss=0.9432, F1 Score=0.8077
# Epoch 273/500 | Train: Loss=0.6318, F1 Score=0.8567 | Val: Loss=0.7744, F1 Score=0.8327
# Epoch 274/500 | Train: Loss=0.5962, F1 Score=0.8451 | Val: Loss=0.7136, F1 Score=0.8334
# Epoch 275/500 | Train: Loss=0.5460, F1 Score=0.8794 | Val: Loss=0.7738, F1 Score=0.8272
# Epoch 276/500 | Train: Loss=0.5227, F1 Score=0.8800 | Val: Loss=0.7466, F1 Score=0.8338
# Epoch 277/500 | Train: Loss=0.5002, F1 Score=0.8848 | Val: Loss=0.7228, F1 Score=0.8432
# Epoch 278/500 | Train: Loss=0.4790, F1 Score=0.8971 | Val: Loss=0.7293, F1 Score=0.8421
# Epoch 279/500 | Train: Loss=0.4632, F1 Score=0.9029 | Val: Loss=0.7175, F1 Score=0.8442
# Epoch 280/500 | Train: Loss=0.4558, F1 Score=0.8999 | Val: Loss=0.6651, F1 Score=0.8421
# Epoch 281/500 | Train: Loss=0.4474, F1 Score=0.9028 | Val: Loss=0.6581, F1 Score=0.8390
# Epoch 282/500 | Train: Loss=0.4450, F1 Score=0.9009 | Val: Loss=0.6681, F1 Score=0.8391
# Epoch 283/500 | Train: Loss=0.4289, F1 Score=0.9077 | Val: Loss=0.6925, F1 Score=0.8421
# Epoch 284/500 | Train: Loss=0.4313, F1 Score=0.9078 | Val: Loss=0.6737, F1 Score=0.8410
# Epoch 285/500 | Train: Loss=0.4251, F1 Score=0.9059 | Val: Loss=0.7019, F1 Score=0.8406
# Epoch 286/500 | Train: Loss=0.4268, F1 Score=0.9062 | Val: Loss=0.7036, F1 Score=0.8396
# Epoch 287/500 | Train: Loss=0.4149, F1 Score=0.9090 | Val: Loss=0.6679, F1 Score=0.8451
# Epoch 288/500 | Train: Loss=0.4135, F1 Score=0.9086 | Val: Loss=0.6861, F1 Score=0.8356
# Epoch 289/500 | Train: Loss=0.4109, F1 Score=0.9100 | Val: Loss=0.6493, F1 Score=0.8469
# Early stopping triggered after 289 epochs.
# Best model restored from epoch 249 with val_f1 0.8819
# CPU times: user 1min 7s, sys: 57 s, total: 2min 4s
# Wall time: 3min 16s

# %%
# @title Plot History
# Create a figure with two side-by-side subplots (two columns)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 5))

# Plot of training and validation loss on the first axis
ax1.plot(training_history['train_loss'], label='Training loss', alpha=0.3, color='#ff7f0e', linestyle='--')
ax1.plot(training_history['val_loss'], label='Validation loss', alpha=0.9, color='#ff7f0e')
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=0.3)

# Plot of training and validation accuracy on the second axis
ax2.plot(training_history['train_f1'], label='Training f1', alpha=0.3, color='#ff7f0e', linestyle='--')
ax2.plot(training_history['val_f1'], label='Validation f1', alpha=0.9, color='#ff7f0e')
ax2.set_title('F1 Score')
ax2.legend()
ax2.grid(alpha=0.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %%
# @title Plot Confusion Matrix
# Collect predictions and ground truth labels
val_preds, val_targets = [], []
with torch.no_grad():  # Disable gradient computation for inference
    for xb, yb in val_loader:
        xb = xb.to(device)

        # Forward pass: get model predictions
        logits = rnn_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store batch results
        val_preds.append(preds)
        val_targets.append(yb.numpy())

# Combine all batches into single arrays
val_preds = np.concatenate(val_preds)
val_targets = np.concatenate(val_targets)

# Calculate overall validation metrics
val_acc = accuracy_score(val_targets, val_preds)
val_prec = precision_score(val_targets, val_preds, average='weighted')
val_rec = recall_score(val_targets, val_preds, average='weighted')
val_f1 = f1_score(val_targets, val_preds, average='weighted')
print(f"Accuracy over the validation set: {val_acc:.4f}")
print(f"Precision over the validation set: {val_prec:.4f}")
print(f"Recall over the validation set: {val_rec:.4f}")
print(f"F1 score over the validation set: {val_f1:.4f}")

# Generate confusion matrix for detailed error analysis
cm = confusion_matrix(val_targets, val_preds)

# Create numeric labels for heatmap annotation
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Visualise confusion matrix
plt.figure(figsize=(8, 7))
sns.heatmap(cm, annot=labels, fmt='',
            cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix — Validation Set')
plt.tight_layout()
plt.show()
# Out:
# Accuracy over the validation set: 0.9000
# Precision over the validation set: 0.8977
# Recall over the validation set: 0.9000
# F1 score over the validation set: 0.8819

# %% [markdown]
# <a id="evaluation"></a>
# ## 11. Evaluation & Metrics
#
# Visualize training history and compute validation metrics.

# %%
rnn_model = RecurrentClassifier(
    input_size=input_shape[-1], # Pass the number of features
    hidden_size=HIDDEN_SIZE,
    num_layers=HIDDEN_LAYERS,
    num_classes=num_classes,
    dropout_rate=DROPOUT_RATE,
    bidirectional=BIDIRECTIONAL,
    rnn_type=RNN_TYPE
    ).to(device)
print("Setting the model to evaluation mode...")
rnn_model.load_state_dict(torch.load(MODEL_LOAD_PATH, map_location=device))
rnn_model.eval()  # Set model to evaluation mode
recurrent_summary(rnn_model, input_size=input_shape)
print("\nStarting model evaluation on test set...")

# Verify data dimensions before inference
print(f"Model input size: {rnn_model.rnn.input_size}")
print(f"Test data feature size: {X_test.shape[-1]}")

test_preds, test_targets = [], []
test_probabilities = []
with torch.no_grad():  # Disable gradient computation for inference
    for xb, yb in test_loader:
        xb = xb.to(torch.float32)
        xb = xb.to(device)

        # Forward pass: get model predictions
        logits = rnn_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store batch results
        test_preds.append(preds)
        test_targets.append(yb.numpy())


# Combine all batches into single arrays
test_preds = np.concatenate(test_preds)
test_targets = np.concatenate(test_targets)

print(f"\nTest set evaluation completed successfully!")
print(f"Total test samples: {len(test_preds)}")
print(f"Predictions shape: {test_preds.shape}")
print(f"Targets shape: {test_targets.shape}")
# Out:
# Setting the model to evaluation mode...
# -------------------------------------------------------------------------------
# Layer (type)              Output Shape                 Param #
# ===============================================================================
# rnn (LSTM)                [[-1, 80, 64], [4, -1, 32]]  43,520
# classifier (Linear)       [-1, 3]                      195
# ===============================================================================
# Total params: 43,715
# Trainable params: 43,715
# Non-trainable params: 0
# -------------------------------------------------------------------------------
#
# Starting model evaluation on test set...
# Model input size: 38
# Test data feature size: 38
#
# Test set evaluation completed successfully!
# Total test samples: 300
# Predictions shape: (300,)
# Targets shape: (300,)

# %% [markdown]
# <a id="model-loading"></a>
# ## 12. Model Loading & Final Testing
#
# Load the trained model and evaluate on the internal test set.

# %% [markdown]
# ### 12.1 Test Set Evaluation

# %% [markdown]
# ### 12.2 Test Set Predictions

# %%
from collections import Counter
import pandas as pd
import numpy as np
import torch

# --- Load and prepare model ---
rnn_model = RecurrentClassifier(
    input_size=input_shape[-1],  # number of features
    hidden_size=HIDDEN_SIZE,
    num_layers=HIDDEN_LAYERS,
    num_classes=num_classes,
    dropout_rate=DROPOUT_RATE,
    bidirectional=BIDIRECTIONAL,
    rnn_type=RNN_TYPE
).to(device)

print("Setting the model to evaluation mode...")
rnn_model.load_state_dict(torch.load(MODEL_LOAD_PATH, map_location=device))
rnn_model.eval()
recurrent_summary(rnn_model, input_size=input_shape)
print("\nStarting model evaluation on test set...")

# --- Check data dimensions ---
print(f"Model input size: {rnn_model.rnn.input_size}")
print(f"Test data feature size: {X_test.shape[-1]}")

# --- Inference ---
test_preds, test_targets = [], []

with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(torch.float32).to(device)

        # Forward pass
        logits = rnn_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        test_preds.append(preds)
        test_targets.append(yb.numpy())

# --- Combine batches ---
test_preds = np.concatenate(test_preds)
test_targets = np.concatenate(test_targets)

print(f"\n✅ Test set evaluation completed successfully!")
print(f"Total test samples: {len(test_preds)}")

# =========================================================
# 🧩 Majority Vote Aggregation per Pirate
# =========================================================
from collections import Counter
import pandas as pd

sample_indices = ids_test  # <-- use your real IDs from build_sequences()

# Combine results into DataFrame
test_df = pd.DataFrame({
    "sample_index": sample_indices,
    "label": test_preds,
    "target": test_targets
})

# Majority vote per pirate
majority_vote = (
    test_df.groupby("sample_index")["label"]
    .apply(lambda x: Counter(x).most_common(1)[0][0])
    .reset_index(name="voted_label")
)

# Majority of targets (optional)
majority_target = (
    test_df.groupby("sample_index")["target"]
    .apply(lambda x: Counter(x).most_common(1)[0][0])
    .reset_index(name="true_label")
)

# Merge and analyze
final_eval_df = majority_vote.merge(majority_target, on="sample_index")

# Optional label decoding
if "pain_map" in globals():
    reverse_pain_map = {v: k for k, v in label_mapping.items()}
    final_eval_df["voted_label"] = final_eval_df["voted_label"].map(reverse_pain_map)
    final_eval_df["true_label"] = final_eval_df["true_label"].map(reverse_pain_map)



# 📊 --- Label Distribution ---
label_counts = final_eval_df["voted_label"].value_counts().reindex(["no_pain", "low_pain", "high_pain"]).fillna(0).astype(int)

print("\n📊  Label Distribution (after Majority Vote):")
for label, count in label_counts.items():
    print(f"   • {label:<10}: {count:>3} pirates")

print(f"\n👥  Total pirates after grouping: {len(final_eval_df)}")


acc = accuracy_score(final_eval_df["true_label"], final_eval_df["voted_label"])
prec = precision_score(final_eval_df["true_label"], final_eval_df["voted_label"], average='weighted')
rec = recall_score(final_eval_df["true_label"], final_eval_df["voted_label"], average='weighted')
f1 = f1_score(final_eval_df["true_label"], final_eval_df["voted_label"], average='weighted')

print(f"\n✅ Accuracy:  {acc:.4f}")
print(f"🎯 Precision: {prec:.4f}")
print(f"📈 Recall:    {rec:.4f}")
print(f"🌟 F1 Score:  {f1:.4f}")
# Out:
# Setting the model to evaluation mode...
# -------------------------------------------------------------------------------
# Layer (type)              Output Shape                 Param #
# ===============================================================================
# rnn (LSTM)                [[-1, 80, 64], [4, -1, 32]]  43,520
# classifier (Linear)       [-1, 3]                      195
# ===============================================================================
# Total params: 43,715
# Trainable params: 43,715
# Non-trainable params: 0
# -------------------------------------------------------------------------------
#
# Starting model evaluation on test set...
# Model input size: 38
# Test data feature size: 38
#
# ✅ Test set evaluation completed successfully!
# Total test samples: 300
#
# 📊  Label Distribution (after Majority Vote):
#    • no_pain   :  43 pirates
#    • low_pain  :  11 pirates
#    • high_pain :   6 pirates
#
# 👥  Total pirates after grouping: 60
#
# ✅ Accuracy:  0.9000
# 🎯 Precision: 0.9174
# 📈 Recall:    0.9000
# 🌟 F1 Score:  0.9063

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Desired label order
class_names = ["no_pain", "low_pain", "high_pain"]

# Compute confusion matrix with fixed label order
cm_test = confusion_matrix(
    final_eval_df["true_label"],
    final_eval_df["voted_label"],
    labels=class_names
)

plt.figure(figsize=(8, 6))

# Format numeric labels for display
labels_text = np.array([f"{num}" for num in cm_test.flatten()]).reshape(cm_test.shape)

sns.heatmap(cm_test, annot=labels_text, fmt='', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix — Test Set (Majority Vote)')
plt.tight_layout()
plt.show()

# %%
cm_raw = confusion_matrix(test_targets, test_preds)
sns.heatmap(cm_raw, annot=True, fmt='d', cmap='Greens',
            xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix — Window Level")
plt.show()

# %% [markdown]
# <a id="submission"></a>
# ## 13. Competition Submission
#
# Generate predictions for the competition test set and create submission file.

# %%
def build_sequences_inference(df, window=40, stride=5):
    dataset = []
    pirate_ids = []

    for pirate_id in df['sample_index'].unique():
        columns = [col for col in df.columns if col not in ['sample_index', 'time', 'label']]
        temp = df[df['sample_index'] == pirate_id][columns].values

        # Padding
        padding_len = window - len(temp) % window
        if padding_len < window:
            padding = np.zeros((padding_len, temp.shape[1]), dtype='float32')
            temp = np.concatenate((temp, padding))

        # Slice into windows
        idx = 0
        while idx + window <= len(temp):
            dataset.append(temp[idx:idx + window])
            pirate_ids.append(pirate_id)  # track which pirate this window came from
            idx += stride

    dataset = np.array(dataset, dtype='float32')
    return dataset, pirate_ids

# %% [markdown]
# ### 13.1 Load & Preprocess Competition Test Data

# %%
# --- Load and preprocess the actual test dataset ---
print("Loading test dataset for final evaluation...")

# Load the actual test dataset (this doesn't have labels)
X_test_final = pd.read_csv('pirate_pain_test.csv')

# Create a mapping dictionary to convert categorical labels to numerical values
map_dict = {'none': 0, 'one': 1, 'two': 2}
X_test_final['n_legs'] = X_test_final['n_legs'].map(map_dict)
X_test_final['n_hands'] = X_test_final['n_hands'].map(map_dict)
X_test_final['n_eyes'] = X_test_final['n_eyes'].map(map_dict)


# Convert inputs from float64 to float32
X_test_final = X_test_final.astype(np.float32)

# Define the columns to be normalised (use training statistics for proper normalization)
scale_columns = [col for col in data.columns
                 if (col.startswith('joint_') or col.startswith('pain_survey')) and not col.startswith('joint_30')]

                 # Use training data statistics for normalization
print("Normalizing test data using training statistics...")
for column in scale_columns:
    if column in df_train.columns:
        # Use training min/max for proper normalization
        train_min = df_train[column].min()
        train_max = df_train[column].max()
        X_test_final[column] = (X_test_final[column] - train_min) / (train_max - train_min)
    else:
        print(f"Warning: Column {column} not found in training data")


print(f"Preprocessed competition test dataset shape: {X_test_final.shape}")

# Generate Sequences
X_test_final_sequence, pirate_ids  = build_sequences_inference(X_test_final, WINDOW_SIZE, STRIDE)
print(f"X_test_final_sequenced shape: {X_test_final_sequence.shape}")
# Out:
# Loading test dataset for final evaluation...
# Normalizing test data using training statistics...
# Preprocessed competition test dataset shape: (211840, 40)
# X_test_final_sequenced shape: (3972, 80, 38)

# %% [markdown]
# ### 13.2 Generate Predictions for Competition

# %%
rnn_model = RecurrentClassifier(
    input_size=input_shape[-1], # Pass the number of features
    hidden_size=HIDDEN_SIZE,
    num_layers=HIDDEN_LAYERS,
    num_classes=num_classes,
    dropout_rate=DROPOUT_RATE,
    bidirectional=BIDIRECTIONAL,
    rnn_type=RNN_TYPE
    ).to(device)
print("Setting the model to evaluation mode...")
rnn_model.load_state_dict(torch.load(MODEL_LOAD_PATH, map_location=device))
rnn_model.eval()  # Set model to evaluation mode
recurrent_summary(rnn_model, input_size=input_shape)

# Verify data dimensions before inference
print(f"Model input size: {rnn_model.rnn.input_size}")
print(f"Test data feature size: {X_test_final_sequence.shape[-1]}")
# Out:
# Setting the model to evaluation mode...
# -------------------------------------------------------------------------------
# Layer (type)              Output Shape                 Param #
# ===============================================================================
# rnn (LSTM)                [[-1, 80, 64], [4, -1, 32]]  43,520
# classifier (Linear)       [-1, 3]                      195
# ===============================================================================
# Total params: 43,715
# Trainable params: 43,715
# Non-trainable params: 0
# -------------------------------------------------------------------------------
# Model input size: 38
# Test data feature size: 38

# %%
X_test_final_tensor = torch.from_numpy(X_test_final_sequence).to(torch.float32).to(device)

final_loader = DataLoader(
    TensorDataset(X_test_final_tensor),
    batch_size=64,  # adjustable
    shuffle=False
)

# Lists to collect results
all_preds = []
all_probs = []

# Disable gradient computation for inference
with torch.no_grad():
    for (xb,) in final_loader:
        xb = xb.to(device)

        # Forward pass through the model
        logits = rnn_model(xb)

        # Convert to probabilities (softmax)
        probs = torch.softmax(logits, dim=1)

        # Get predicted class (highest probability)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store results
        all_preds.append(preds)
        all_probs.append(probs.cpu().numpy())

# Combine all batches
all_preds = np.concatenate(all_preds)
all_probs = np.concatenate(all_probs)

print(f"\n✅ Final prediction completed!")


# Combine predictions with pirate IDs
pred_df = pd.DataFrame(
    {
        "sample_index": pirate_ids,
        "label": all_preds
    }
)

# Group by pirate and choose the most common prediction (majority vote)
final_preds = (
    pred_df.groupby("sample_index")["label"]
    .apply(lambda x: Counter(x).most_common(1)[0][0])
    .reset_index()
)
pain_map = {'no_pain': 0, 'low_pain': 1, 'high_pain': 2}
reverse_pain_map = {v: k for k, v in pain_map.items()}
final_preds["label"] = final_preds["label"].map(reverse_pain_map)

final_preds["sample_index"] = final_preds["sample_index"].astype(int).astype(str).str.zfill(3)



print(f"Final predictions shape: {final_preds.shape}")
print(final_preds.head())

final_preds[["sample_index", "label"]].to_csv(f"submissions/{SUBMISSION_FILENAME}", index=False)
print(f"✅ Saved submissions/{SUBMISSION_FILENAME}")

# Count number of pirates in each predicted label category
label_counts = final_preds["label"].value_counts().sort_index()

print("\n📊 Label distribution (number of pirates per pain level):")
for label, count in label_counts.items():
    print(f"{label}: {count}")

# Optional: quick sanity check — should equal total number of pirates
print(f"\nTotal pirates: {label_counts.sum()}")
# Out:
# ✅ Final prediction completed!
# Final predictions shape: (1324, 2)
#   sample_index    label
# 0          000  no_pain
# 1          001  no_pain
# 2          002  no_pain
# 3          003  no_pain
# 4          004  no_pain
# ✅ Saved submissions/LSTM_bi_11-11-00-21.csv
#
# 📊 Label distribution (number of pirates per pain level):
# high_pain: 16
# low_pain: 54
# no_pain: 1254
#
# Total pirates: 1324

# %% [markdown]
# ### 13.3 Create Submission File

# %% [markdown]
# ### 13.4 Validate Submission Format

# %%
# --- Validate Submission Format ---
print("Validating submission file format...")
submission_filepath = f"submissions/{EXPERIMENT_NAME}.csv"
submission_df = pd.read_csv(f"submissions/{SUBMISSION_FILENAME}")
# Load the sample submission for comparison
sample_submission = pd.read_csv('sample_submission.csv')
print(f"Sample submission shape: {sample_submission.shape}")
print(f"Our submission shape: {submission_df.shape}")

# Check format compatibility
if submission_df.shape[0] != sample_submission.shape[0]:
    print(f"⚠️  WARNING: Different number of samples!")
    print(f"Expected: {sample_submission.shape[0]}, Got: {submission_df.shape[0]}")
else:
    print("✅ Number of samples matches sample submission")

# Check column names
if list(submission_df.columns) == list(sample_submission.columns):
    print("✅ Column names match sample submission")
else:
    print(f"⚠️  WARNING: Column names mismatch!")
    print(f"Expected: {list(sample_submission.columns)}")
    print(f"Got: {list(submission_df.columns)}")

# Check sample_index format
expected_indices = [f"{i:03d}" for i in range(len(sample_submission))]
if list(submission_df['sample_index']) == expected_indices:
    print("✅ Sample indices format is correct")
else:
    print("⚠️  WARNING: Sample indices format might be incorrect")
    print(f"First few expected: {expected_indices[:5]}")
    print(f"First few got: {list(submission_df['sample_index'][:5])}")

# Check label values
expected_labels = set(sample_submission['label'].unique())
our_labels = set(submission_df['label'].unique())
if our_labels.issubset(expected_labels):
    print("✅ All label values are valid")
    print(f"Used labels: {sorted(our_labels)}")
else:
    print(f"⚠️  WARNING: Invalid label values detected!")
    print(f"Expected labels: {sorted(expected_labels)}")
    print(f"Our labels: {sorted(our_labels)}")
    print(f"Invalid labels: {our_labels - expected_labels}")

print(f"\\n🎯 Final submission file: '{submission_filepath}'")
print("📊 Submission ready for competition!")

# Display final summary
print(f"\\n" + "="*60)
print("                    SUBMISSION SUMMARY")
print("="*60)
print(f"Model: {rnn_model.rnn_type} (Bidirectional: {rnn_model.bidirectional})")
print(f"Architecture: {rnn_model.hidden_size} hidden units, {rnn_model.num_layers} layers")
print(f"Total Parameters: {sum(p.numel() for p in rnn_model.parameters()):,}")
print(f"Test Performance (Internal): F1={test_f1:.4f}, Accuracy={test_accuracy:.4f}")
print(f"Competition Samples: {len(submission_df)}")
print(f"Submission File: {submission_filepath}")
print("="*60)
# Out:
# Validating submission file format...
# Sample submission shape: (1324, 2)
# Our submission shape: (1324, 2)
# ✅ Number of samples matches sample submission
# ✅ Column names match sample submission
# ⚠️  WARNING: Sample indices format might be incorrect
# First few expected: ['000', '001', '002', '003', '004']
# First few got: [0, 1, 2, 3, 4]
# ✅ All label values are valid
# Used labels: ['high_pain', 'low_pain', 'no_pain']
# \n🎯 Final submission file: 'submissions/LSTM_bi_11-11-00-21.csv'
# 📊 Submission ready for competition!
# \n============================================================
#                     SUBMISSION SUMMARY
# ============================================================
# Model: LSTM (Bidirectional: True)
# Architecture: 32 hidden units, 2 layers
# Total Parameters: 43,715
# Test Performance (Internal): F1=0.8640, Accuracy=0.8633
# Competition Samples: 1324
# Submission File: submissions/LSTM_bi_11-11-00-21.csv
# ============================================================

# %% [markdown]
# ## 14 Tensor Board

# %%
## Copy TensorBoard logs to accessible location for Colab
#!rsync -a $current_dir"/"$logs_dir/ "/content/"$logs_dir
## Launch TensorBoard interface
#%tensorboard --logdir "/content/"$logs_dir

# %% [markdown]
# ## 15. Save Model Configuration

# %%
# Gather all relevant model and training parameters
model_config = {
    'EXPERIMENT_NAME': EXPERIMENT_NAME,
    'RNN_TYPE': RNN_TYPE,
    'BIDIRECTIONAL': BIDIRECTIONAL,
    'input_size': input_shape[-1],
    'num_classes': num_classes,
    'HIDDEN_SIZE': HIDDEN_SIZE,
    'HIDDEN_LAYERS': HIDDEN_LAYERS,
    'DROPOUT_RATE': DROPOUT_RATE,
    'LEARNING_RATE': LEARNING_RATE,
    'EPOCHS': EPOCHS,
    'PATIENCE': PATIENCE,
    'L1_LAMBDA': L1_LAMBDA,
    'L2_LAMBDA': L2_LAMBDA,
    'BATCH_SIZE': BATCH_SIZE,
    'WINDOW_SIZE': WINDOW_SIZE,
    'STRIDE': STRIDE,
    'SEED': SEED,
    'one_pirate_window': one_pirate_window,
    'TEST_F1': f'{f1:.4f}'
}

# Define the path to save the config file
config_filepath = os.path.join(models_dir, f"{EXPERIMENT_NAME}_config.json")

# Save the dictionary as a JSON file
with open(config_filepath, 'w') as f:
    json.dump(model_config, f, indent=4)

print(f"✅ Model configuration saved to '{config_filepath}'")

# Display the saved configuration
print("\n--- Saved Model Configuration ---")
print(json.dumps(model_config, indent=4))
print("-----------------------------------")
# Out:
# ✅ Model configuration saved to 'models/LSTM_bi_11-11-00-21_config.json'
#
# --- Saved Model Configuration ---
# {
#     "EXPERIMENT_NAME": "LSTM_bi_11-11-00-21",
#     "RNN_TYPE": "LSTM",
#     "BIDIRECTIONAL": true,
#     "input_size": 38,
#     "num_classes": 3,
#     "HIDDEN_SIZE": 32,
#     "HIDDEN_LAYERS": 2,
#     "DROPOUT_RATE": 0.3,
#     "LEARNING_RATE": 0.001,
#     "EPOCHS": 500,
#     "PATIENCE": 40,
#     "L1_LAMBDA": 0.0001,
#     "L2_LAMBDA": 0.001,
#     "BATCH_SIZE": 512,
#     "WINDOW_SIZE": 80,
#     "STRIDE": 40,
#     "SEED": 42,
#     "one_pirate_window": true,
#     "TEST_F1": "0.9063"
# }
# -----------------------------------
